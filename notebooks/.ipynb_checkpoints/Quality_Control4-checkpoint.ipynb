# %%
import re
import os

import pysam
import gzip

import pandas as pd
import numpy as np

import skbio
import dna
import Bio
from Bio import SeqIO

import matplotlib.pyplot as plt
import matplotlib

from spikedisplay import plotting, io
from importlib import reload
reload(plotting)
plotting.set_styles(plt, matplotlib)
# Out:
# font.sans-serif Arial
# mathtext.default regular

# %%
jrr_dir = '/root/projects/dms/output/plasmid1_JRR'
jpc_dir = '/root/projects/dms/output/plasmid1_JPC'
 
merged_read_fn = "Plasmid-Lib1_S7_L001_001.merged.demuxed.fastq.gz"

# %%
jpc_records, jpcdf = io.get_records_df(jpc_dir, reads_fn=merged_read_fn)
jrr_records, jrrdf = io.get_records_df(jrr_dir, reads_fn=merged_read_fn)
booldex = ~jrrdf.sequence.isin(list(jpcdf.sequence))
only_jrr = jrrdf[booldex]
# Out:
# Found directory at /root/projects/dms/output/plasmid1_JPC
# Found file at /root/projects/dms/output/plasmid1_JPC/Plasmid-Lib1_S7_L001_001.merged.demuxed.fastq.gz
# Found directory at /root/projects/dms/output/plasmid1_JRR
# Found file at /root/projects/dms/output/plasmid1_JRR/Plasmid-Lib1_S7_L001_001.merged.demuxed.fastq.gz

# %%
fig = plt.figure(figsize=(6, 6))
fig.set_dpi(150)

kwargs ={
        'alpha': 1
}

dfs = {'jpc_data': jpcdf,
       'jrr_data': jrrdf,
       'jrr_not_in_jpc': only_jrr}

yvar = 'length'

ticks = np.arange(0, 6, 1)
logticks = np.power(10, ticks)
colors = ['purple', 'green', 'black']
bin_ns = [100, 100, 3]
i = 1
for key, df in dfs.items():
    ax = fig.add_subplot(3, 1, i)
    y = df[yvar]
    rng = np.max(y) - np.min(y)
    n_bins = int(np.round(rng/10))
    n_bins = bin_ns[i-1]
    ax.hist(y, color=colors[i-1], bins=n_bins, **kwargs)
    ax.set_title(key)
    
    ax.set_yscale('log')
    ax.set_xlabel('Sequence Length')
    ax.set_ylabel('# of Reads')
    ax.set_xlim(200, 500)
    ax.set_xticks([200, 250, 300, 350, 400, 450, 500])
    ax.set_yticks(logticks)
    
    i +=1
    
# plt.show()
plt.tight_layout()

# %% [markdown]
# # Number of unique mutants between workflow steps

# %%
import re
import os

import pysam
import gzip

import pandas as pd
import numpy as np

import skbio
import dna
import Bio
from Bio import SeqIO

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

from spikedisplay import plotting, io
from importlib import reload
for mod in [plotting, io]:
    reload(mod)
# plotting.set_styles(plt, matplotlib)

AMINO_ACID_ORDER = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y', "*"]

# %%
output_dir = '/root/projects/dms/output'
# spikedisplay.io.create_all_bam_df() matches barcode in the bam
# sequence id to true barcodes in constants.rbd_barcode_index 
# using a fuzzy lookup with cdifflib and assigns bin number.
# If no good barcode match found, then bin is assigned 0
alldf, dfs = io.create_all_bam_df(output_dir)
# Out:
# FLAG-Lib2_S4_L001_001_bam.csv.gz
# /root/venvs/.dms/lib/python3.6/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# FLAG-Lib1_S3_L001_001_bam.csv.gz
# Integrated-Lib2_S6_L001_001_bam.csv.gz
# ACE2-Lib1_S1_L001_001_bam.csv.gz
# Plasmid-Lib2_S8_L001_001_bam.csv.gz
# Plasmid-Lib1_S7_L001_001_bam.csv.gz
# Integrated-Lib1_S5_L001_001_bam.csv.gz
# ACE2-Lib2_S2_L001_001_bam.csv.gz

# %%
# filter alldf down to only mutants with a certain number of reads
thresh = 0
cols = ['mutant_aa', 'mismatch_index_in_full_length_wt_seq', 'sample_name']

groupdf = alldf.groupby(cols).count()
indices = groupdf.loc[groupdf.seq_id>=thresh, :].index

alldf_100 = alldf.set_index(cols).loc[indices, :]

filtered_df = alldf_100.copy()
cols = ['mutant_aa', 'mismatch_index_in_full_length_wt_seq']

counts = []
names = []
libraries = []
i=0
fns = list(filtered_df.source_file.unique())
dfs = []
for filename in fns:
    newdf = filtered_df[filtered_df.source_file==filename]
    newdf.reset_index(inplace=True)
    dfs.append(newdf)
for df in dfs:
    
    print(f'Analyzing bamdf {i+1} of {len(dfs)}')
    df.set_index(cols, inplace=True)
    sample_name = df.sample_name.iloc[0]
    library = df.library_name.iloc[0]
    n_unique_mutants = len(df.index.unique())
    counts.append(n_unique_mutants)
    names.append(sample_name)
    libraries.append(library)
    
    i+=1
    
    df.reset_index(inplace=True)
    
count_dict = {'sample_name': names,
              'n_unique_mutants': counts,
              'library': libraries}
count_df = pd.DataFrame(count_dict)
# Out:
# Analyzing bamdf 1 of 8
# Analyzing bamdf 2 of 8
# Analyzing bamdf 3 of 8
# Analyzing bamdf 4 of 8
# Analyzing bamdf 5 of 8
# Analyzing bamdf 6 of 8
# Analyzing bamdf 7 of 8
# Analyzing bamdf 8 of 8

# %%
x_order = [
    'Plasmid',
    'Integrated',
    'FLAG',
    'ACE2',
]

hue_order = ['Lib1',
             'Lib2']

fig = plt.figure(figsize=(4, 2))
fig.set_dpi(300)
ax = fig.add_subplot(111)

kwargs = {
    'y': 'sample_name',
    'x': 'n_unique_mutants',
    'order': x_order,
    'data': count_df,
    'orient': 'horizontal',
    'palette': 'hls'
}

sns.barplot(**kwargs)

for spine in [ax.spines[key] for key in ['top', 'right']]:
    spine.set_visible(False)

ax.set_xlim(0, 4000)
ax.xaxis.set_minor_locator(MultipleLocator(200))
ax.set_title(f'Unique mutants across lib1,2\n with >={thresh} reads')
plt.tight_layout()
fig.savefig(f'coverage_summary_with_over_{thresh}_reads.jpg')

# %% [markdown]
# ## Histogram of number of sequences with x number of reads per sample

# %%
cols = ['mutant_aa', 'mismatch_index_in_full_length_wt_seq', 'sample_name']
groupdf = alldf.groupby(cols).count().reset_index()
# Get rid of wild-type since it dominates the histogram
filt_groupdf = groupdf[groupdf.mismatch_index_in_full_length_wt_seq!=-1]
def annotate(data, **kwargs):
    threshold = kwargs.get('threshold', 10)
    xpos = kwargs.get('xpos', 0.1)
    ypos = kwargs.get('ypos', 0.6)
    n = len(data[data.seq_id<threshold])
    ax = plt.gca()
    ax.text(xpos, ypos, f'{n} mutants with <{threshold} reads', transform=ax.transAxes)

hue_order = ['Plasmid', 'Integrated', 'FLAG', 'ACE2']

gridkwargs = {
    'data': filt_groupdf,
    'row': 'sample_name',
    'hue': 'sample_name',
    'palette': 'hls',
    'hue_order': hue_order,
    'row_order': hue_order,
    'sharex': False
}
histkwargs = {
    'x': 'seq_id'
}
g = sns.FacetGrid(**gridkwargs)
g.map_dataframe(sns.histplot, **histkwargs)
g.map_dataframe(annotate, threshold=10)
g.map_dataframe(annotate, threshold=100, ypos=0.5)

g.set_axis_labels('Number of reads', 'Number of mutants\nwith x reads')
g.figure.set_figheight(8)
g.figure.set_figwidth(4)
g.figure.set_dpi(300)
g.set(xticks=np.arange(0, 1000, 100))
g.set(xlim=(-20, 1000))
plt.tight_layout()
g.figure.savefig('RBD_counts_per_mutant_hists_over_samples.jpg')

# %%
# If only middle third amplified, what is maximal coverage?
total_aa = 201
section = 201/3
total = section * 20
total
# Out:
# 1340.0

# %% [markdown]
# ## Correlation of coverage between steps in library generation, integration, and sorting

# %%
cols = ['variant_name',
        'sample_library',
        'library_name',
        'sample_name']
groupdf = alldf.groupby(cols).count().reset_index()
# Get rid of wild-type since it dominates the histogram
filt_groupdf = groupdf[groupdf.mismatch_index_in_full_length_wt_seq!=-1]

# %%
plasmid1df = filt_groupdf[filt_groupdf.sample_library=='Plasmid-Lib1'].reset_index()
plasmid2df = filt_groupdf[filt_groupdf.sample_library=='Plasmid-Lib2'].reset_index()

lib1df = filt_groupdf[filt_groupdf.library_name=='Lib1'].reset_index()
lib2df = filt_groupdf[filt_groupdf.library_name=='Lib2'].reset_index()

# %%
plotting.plot_library_correlations(plasmid2df, lib2df)
# Out:
# /root/projects/spikedisplay/spikedisplay/plotting.py:148: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(xlim)
# /root/projects/spikedisplay/spikedisplay/plotting.py:149: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_ylim(ylim)
# Saved figure at /root/projects/spikedisplay/notebooks/Plasmid-Lib2_variant_coverage_correlations.png

# %%
plotting.plot_library_correlations(plasmid1df, lib1df)
# Out:
# Saved figure at /root/projects/spikedisplay/notebooks/Plasmid-Lib1_variant_coverage_correlations.png

# %% [markdown]
# # Summarize read loss over various processing steps

# %%
import re
import os

import pysam
import gzip

import pandas as pd
import numpy as np

import skbio
import dna
import Bio
from Bio import SeqIO

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

from spikedisplay import plotting, io, constants
from importlib import reload
for mod in [plotting, io, constants]:
    reload(mod)
plotting.set_styles(plt, matplotlib)
# Out:
# font.sans-serif Arial
# mathtext.default regular

# %%
# Read in barcoded alignment files so we can count those
output_dir = '/root/projects/dms/output'
alldf, dfs = io.create_all_bam_df(output_dir)
bcdf = constants.rbd_barcode_index
# Out:
# FLAG-Lib2_S4_L001_001_bam.csv.gz
# FLAG-Lib1_S3_L001_001_bam.csv.gz
# Integrated-Lib2_S6_L001_001_bam.csv.gz
# ACE2-Lib1_S1_L001_001_bam.csv.gz
# Plasmid-Lib2_S8_L001_001_bam.csv.gz
# Plasmid-Lib1_S7_L001_001_bam.csv.gz
# Integrated-Lib1_S5_L001_001_bam.csv.gz
# ACE2-Lib2_S2_L001_001_bam.csv.gz

# %%
outputdir = '/root/projects/dms/output/'
filename = 'qc-counts.csv'
filepath = os.path.join(outputdir, filename)

qccountsdf = pd.read_csv(filepath, header=None)
qccountsdf.columns = ['sample_name', 'reads_type', 'n_reads']
qccountsdf.head()
# Out:
#                    sample_name     reads_type  n_reads
# 0        FLAG-Lib1_S3_L001_001  Forward_reads   659759
# 1  Integrated-Lib2_S6_L001_001  Forward_reads   831534
# 2  Integrated-Lib1_S5_L001_001  Forward_reads   852805
# 3     Plasmid-Lib1_S7_L001_001  Forward_reads   795422
# 4        ACE2-Lib2_S2_L001_001  Forward_reads   883818

# %%
# Add barcoded read numbers and numbers not wild type
source_files = alldf.source_file.unique()
sample_names = [f.replace('_bam.csv.gz', '') for f in source_files]
barcoded_reads = [len(df[df.bin_number!=0]) for df in dfs]
barcoded_dfs = [df[df.bin_number!=0] for df in dfs]
nonwt_reads = [len(df[~df.is_wt]) for df in barcoded_dfs]
wt_reads = [len(df[df.is_wt]) for df in barcoded_dfs]
barcoded_reads_dict = dict(zip(sample_names, barcoded_reads))

reads_type = 'barcode_called_reads'
dicts = [dict(zip(sample_names, reads)) for reads in [barcoded_reads, nonwt_reads, wt_reads]]
reads_types = ['barcoded_reads', 'non-wt_reads', 'wt_reads']
for i, reads_type in enumerate(reads_types):
    reads_dict = dicts[i]
    for key, val in reads_dict.items():
        print(key, val)
        rowdict = {
            'sample_name': key,
            'reads_type': reads_type,
            'n_reads': val
        }
        index = qccountsdf.index.max() + 1
        qccountsdf = qccountsdf.append(pd.DataFrame(rowdict, index=[index]),
                                       ignore_index=False)

sample_labels = qccountsdf.sample_name.str[0:-12]
qccountsdf.loc[: , 'sample_label'] = sample_labels
# Out:
# FLAG-Lib2_S4_L001_001 209351
# FLAG-Lib1_S3_L001_001 162052
# Integrated-Lib2_S6_L001_001 198886
# ACE2-Lib1_S1_L001_001 228613
# Plasmid-Lib2_S8_L001_001 237664
# Plasmid-Lib1_S7_L001_001 257897
# Integrated-Lib1_S5_L001_001 205613
# ACE2-Lib2_S2_L001_001 208081
# FLAG-Lib2_S4_L001_001 63761
# FLAG-Lib1_S3_L001_001 40709
# Integrated-Lib2_S6_L001_001 57990
# ACE2-Lib1_S1_L001_001 58650
# Plasmid-Lib2_S8_L001_001 76630
# Plasmid-Lib1_S7_L001_001 75992
# Integrated-Lib1_S5_L001_001 53106
# ACE2-Lib2_S2_L001_001 54841
# FLAG-Lib2_S4_L001_001 145590
# FLAG-Lib1_S3_L001_001 121343
# Integrated-Lib2_S6_L001_001 140896
# ACE2-Lib1_S1_L001_001 169963
# Plasmid-Lib2_S8_L001_001 161034
# Plasmid-Lib1_S7_L001_001 181905
# Integrated-Lib1_S5_L001_001 152507
# ACE2-Lib2_S2_L001_001 153240

# %%
reload(plotting)
# Out:
# <module 'spikedisplay.plotting' from '/root/projects/spikedisplay/spikedisplay/plotting.py'>

# %%
sample_order = [
    'Plasmid-Lib1',
    'Plasmid-Lib2',
    'Integrated-Lib1',
    'Integrated-Lib2',
    'FLAG-Lib1',
    'FLAG-Lib2',
    'ACE2-Lib1',
    'ACE2-Lib2'
]

wanted_read_types = [
    'Forward_reads',
    'Forward_trimmed_reads',
    'Reverse_trimmed_reads',
    'Forward_paired_reads',
    'Merged_reads',
    'Aligned_reads',
    'barcoded_reads',
    'wt_reads',
    'non-wt_reads'
]



fig = plt.figure(figsize=(3, 6))
fig.set_dpi(300)
ax = fig.add_subplot(111)
df = qccountsdf[qccountsdf.reads_type.isin(wanted_read_types)]

barkwargs = {
    'y': 'sample_label',
    'x': 'n_reads',
    'hue': 'reads_type',
    'order': sample_order,
    'hue_order': wanted_read_types,
    'orientation': 'horizontal',
    'ax': ax,
    'data': df,
    'palette': 'Spectral'
}
fontsize = 14
sns.barplot(**barkwargs)

for spine in [ax.spines[name] for name in ['top', 'right']]:
    spine.set_visible(False)
ax.legend(bbox_to_anchor=(1, 1))

plotting.human_format(ax, axname='x')
plotting.format_ticks(ax, format_y_ticks=False, tickdirection='out')

ax.set_ylabel('')
ax.set_xlabel('# of reads', fontsize=fontsize)
axlabels = ax.get_yticklabels()
ax.set_yticklabels(axlabels, fontsize=fontsize)
# Out:
# [Text(0, 0, 'Plasmid-Lib1'),
#  Text(0, 0, 'Plasmid-Lib2'),
#  Text(0, 0, 'Integrated-Lib1'),
#  Text(0, 0, 'Integrated-Lib2'),
#  Text(0, 0, 'FLAG-Lib1'),
#  Text(0, 0, 'FLAG-Lib2'),
#  Text(0, 0, 'ACE2-Lib1'),
#  Text(0, 0, 'ACE2-Lib2')]

# %% [markdown]
# ### Stacked bar

# %%
sample_order = [
    'Plasmid-Lib1',
    'Plasmid-Lib2',
    'Integrated-Lib1',
    'Integrated-Lib2',
    'FLAG-Lib1',
    'FLAG-Lib2',
    'ACE2-Lib1',
    'ACE2-Lib2'
]

wanted_read_types = [
    'Forward_reads',
    'Forward_paired_reads',
    'Merged_reads',
    'Aligned_reads',
    'barcoded_reads',
    'non-wt_reads'
]

read_type_labels = [
    'Failed to trim + pair',
    'Failed to merge fwd and rev',
    'Failed to align to WT',
    'Failed to match barcode to index',
    'Barcoded, aligned WT reads',
    'Barcoded, aligned non-WT reads'
]

# wanted_read_types.reverse()

fig = plt.figure(figsize=(3, 4))
fig.set_dpi(300)
ax = fig.add_subplot(111)
df = qccountsdf[qccountsdf.reads_type.isin(wanted_read_types)]

barkwargs = {
    'y': 'sample_label',
    'x': 'n_reads',
    'hue': 'reads_type',
    'order': sample_order,
    'hue_order': wanted_read_types,
    'orientation': 'horizontal',
    'ax': ax,
    'data': df,
    'palette': 'Spectral',
    'dodge': False
}
fontsize = 12
sns.barplot(**barkwargs)


# Formatting stuff
for spine in [ax.spines[name] for name in ['top', 'right']]:
    spine.set_visible(False)

plotting.format_ticks(ax, format_y_ticks=False, tickdirection='out')
plotting.human_format(ax, axname='x')

ax.set_ylabel('')
ax.set_xlabel('# of reads', fontsize=fontsize)
yticklabels = ax.get_yticklabels()
ax.set_yticklabels(yticklabels, fontsize=fontsize)
h, l = ax.get_legend_handles_labels()
ax.legend(h, read_type_labels, bbox_to_anchor=(1, 1), frameon=False)

# %% [markdown]
# # Assigning functional score to variants

# %%
import re
import os

import pysam
import gzip

import pandas as pd
import numpy as np

import skbio
import dna
import Bio
from Bio import SeqIO

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

from spikedisplay import plotting, io, constants, fitting, normalization
from importlib import reload
for mod in [plotting, io, constants, fitting, normalization]:
    reload(mod)
plotting.set_styles(plt, matplotlib)

# Read in barcoded alignment files so we can count those

output_dir = '/root/projects/dms/output'
alldf, dfs = io.create_all_bam_df(output_dir)
bcdf = constants.rbd_barcode_index
# Out:
# font.sans-serif Arial
# mathtext.default regular
# FLAG-Lib2_S4_L001_001_bam.csv.gz
# /root/venvs/.dms/lib/python3.6/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# FLAG-Lib1_S3_L001_001_bam.csv.gz
# Integrated-Lib2_S6_L001_001_bam.csv.gz
# ACE2-Lib1_S1_L001_001_bam.csv.gz
# Plasmid-Lib2_S8_L001_001_bam.csv.gz
# Plasmid-Lib1_S7_L001_001_bam.csv.gz
# Integrated-Lib1_S5_L001_001_bam.csv.gz
# ACE2-Lib2_S2_L001_001_bam.csv.gz

# %%
22911930/6600000
# Out:
# 3.4715045454545455

# %%
new_reads = 600000

read_fractions = readsperbin.seq_id/(np.sum(readsperbin.seq_id))

added_reads = read_fractions*new_reads

# %%
added_reads/cell_counts
# Out:
# bin_number
# 1    0.042711
# 2    0.202294
# 3    0.287968
# 4    0.119940
# Name: seq_id, dtype: float64

# %%
6600000/99648
# Out:
# 66.23314065510597

# %%
plt.plot(cell_counts)

# %%
wanted_samples = ['ACE2-Lib1',
                  'FLAG-Lib1']

reads_threshold = 200

dfs = [df for df in dfs if df.sample_library.iloc[0] in wanted_samples]
# Get rid of reads with unassigned bin from barcode
dfs = [df[df.bin_number!=0] for df in dfs]
# Choose the ACE2-Lib1 sample
df = dfs[1]
# This is manually entered. It's the number of cell counts
# per bin from Ankur. Order is bin 1-4
cell_counts = [
    486299,
    561610,
    1497420,
    286894
]
readsperbin.loc[:, 'number_of_cells'] = cell_counts
# Optionally get rid of wild-type sequences
# df = df[df.is_wt==False]

count_gb_index = [
        'is_wt',
        'mutant_aa',
        'wt_aa_at_mismatch',
        'mismatch_index_in_full_length_wt_seq',
        'source_file',
        'sample_name',
        'library_name',
        'variant_name',
        'sample_library',
        'bin_number'
    ]

dfcount = df.groupby(count_gb_index).count().reset_index()
# Only keep variants with over a certain number of reads each
# before calculating normalized bins
keep_variants = []
dfcount.set_index(['variant_name'], inplace=True)
for variant in list(dfcount.index.unique()):
    if np.sum(dfcount.loc[variant, 'seq_id']) > reads_threshold:
        keep_variants.append(variant)

dfcount = dfcount.loc[keep_variants, :]

df = df[df.variant_name.isin(keep_variants)]
readsperbin = df.groupby(['bin_number']).count()
readsperbin.loc[:, 'number_of_cells'] = cell_counts
readsperbin.loc[:, 'nreads_to_ncells'] = readsperbin.seq_id/readsperbin.number_of_cells

total_reads_in_sample = readsperbin['seq_id'].sum()
total_cells_in_sample = readsperbin['number_of_cells'].sum()
for bin_number in [1, 2, 3, 4]:
    
    total_reads_in_bin = readsperbin.loc[bin_number, 'seq_id']
    total_cells_in_bin = readsperbin.loc[bin_number, 'number_of_cells']
    bin_fraction_reads = total_reads_in_bin/total_reads_in_sample
    bin_fraction_cells = total_cells_in_bin/total_cells_in_sample
    # Can either use bin_fraction cells or bin_fraction_reads to 
    # normalize variant read counts per bin to fraction of all reads
    # found in that bin.
    # Based on Starr et al. 2020 Cell,if read counts per bin are lower
    # than cell counts per bin, potentially cell counts should be used to weight
    # bins. Otherwise, the ratio of read:cell count per bin should be
    # used
    weight = 1/bin_fraction_reads
    print(f'{total_reads_in_bin} reads for bin {bin_number} ({bin_fraction_reads}, {weight})')
    boolean = dfcount.bin_number==bin_number
    dfcount.loc[boolean, normcolname] = dfcount.loc[boolean, 'seq_id']/total_reads_in_bin
    dfcount.loc[boolean, 'bin_fraction'] = bin_fraction
    dfcount.loc[boolean, 'bin_weight'] = weight
    
dfcount.loc[:, 'unweighted_variant_reads_in_bin'] = dfcount.seq_id
dfcount.loc[:, 'weighted_variant_reads_in_bin'] = dfcount.bin_weight*dfcount.unweighted_variant_reads_in_bin

dfcount.reset_index(inplace=True)
# Out:
# 6093 reads for bin 1 (0.03324693749488446, 30.077958312817987)
# 33109 reads for bin 2 (0.18066188306550623, 5.535201908846537)
# 133572 reads for bin 3 (0.7288462063132622, 1.3720315635013325)
# 10491 reads for bin 4 (0.05724497312634709, 17.468782766180535)

# %%
fig = plt.figure(figsize=(3, 2))
ax = fig.add_subplot(111)
fig.set_dpi(300)
violinkwargs = {
    'x': 'bin_number',
    'y':'unweighted_variant_reads_in_bin',
    'hue': 'variant_name',
    'data': dfcount,
    'legend': False,
    'ax': ax
}

sns.lineplot(**violinkwargs)
ax.set_ylim(0, 500)
# Out:
# (0.0, 500.0)

# %%
fig = plt.figure(figsize=(3, 2))
ax = fig.add_subplot(111)
fig.set_dpi(300)

violinkwargs = {
    'x': 'bin_number',
    'y':'weighted_variant_reads_in_bin',
    'hue': 'variant_name',
    'data': dfcount,
    'legend': False
}

sns.lineplot(**violinkwargs)

sns.lineplot(**violinkwargs)
ax.set_ylim(0, 700)
# Out:
# (0.0, 700.0)

# %%
weighted_mean
# Out:
# 2.50320035584173

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
y
# Out:
# array([169831.45394737, 168599.29511847, 170249.74538398, 170730.87595768])

# %%
weights*x
# Out:
# array([0.24996852, 0.4963099 , 0.75175256, 1.00516938])

# %%
weights
# Out:
# array([0.24996852, 0.24815495, 0.25058419, 0.25129234])

# %%
# Weighting bin number by number of reads in that bin
xvar = 'bin_number'
yvar = 'weighted_variant_reads_in_bin'

dfc = dfcount.set_index('variant_name')
dfc.loc[:, 'weighted_mean_bin'] = np.nan
dfc.loc[:, 'total_variant_reads'] = np.nan
dfc.loc[:, 'gaussian_center_norm_bin_reads'] = np.nan
dfc.loc[:, 'mode_bin'] = np.nan
constraints = (0, [1000, 6., 6.])

xs = []
ys = []
total_reads = []
for variant in dfc.index.unique():
    print(variant)
    x = np.array(dfc.loc[variant, xvar])
    y = np.array(dfc.loc[variant, yvar])
    x, y = fitting.fill_in_bins(x, y, unique_bins=[1, 2, 3, 4])
    mode_bin = x[np.argmax(y)]
#     popt, pcov = fitting.curve_fit(fitting.gaussian, x, y, bounds=constraints)
#     center = popt[1]
    dfc.loc[variant, 'gaussian_center_norm_bin_reads'] = center
    dfc.loc[variant, 'mode_bin'] = mode_bin
    xs.append(x)
    ys.append(y)
    weights = y/np.sum(y)
    weighted_mean = np.sum(weights*x)
    dfc.loc[variant, 'weighted_mean_bin'] = weighted_mean
    # seq_id is sum of filled values in the seq_id column
    # of the bam_df (one row per unique read)
    total_variant_reads = dfc.loc[variant, 'seq_id'].sum()
    dfc.loc[variant, 'total_variant_reads'] = total_variant_reads
    total_reads.append(total_variant_reads)
if 'bin_number' in count_gb_index:
    count_gb_index.remove('bin_number')

fits_df = dfc.pivot_table(index=count_gb_index, aggfunc=np.median).reset_index()
# Out:
# G83C
# G86C
# G117C
# W106C
# E76D
# E135D
# E141D
# V65E
# D97H
# P133H
# Q79H
# Q84H
# R136I
# Q84K
# Q144K
# F70L
# F134L
# R78L
# R124L
# W106L
# L111M
# L122M
# L131M
# D97N
# K87N
# K114N
# A145P
# P82Q
# R127S
# T140S
# P82T
# D59Y
# D68Y
# D75Y
# D90Y
# D97Y
# D98Y
# D137Y
# S69Y
# S108Y
# S129Y
# S139Y
# None0None

# %%
i = np.random.randint(0, len(xs))
print(total_reads[i])
plt.scatter(xs[i], ys[i])
# Out:
# 155

# %%
wt_booldex = fits_df.variant_name=='None0None'
wt_mean_bin = fits_df.loc[wt_booldex, 'mode_bin'].iloc[0]

fits_df.loc[:, 'ratio_to_wt'] = fits_df.weighted_mean_bin/wt_mean_bin
fits_df.loc[:, 'log2_ratio_to_wt'] = np.log2(fits_df.ratio_to_wt)

# %%
xvar = 'mode_bin'

# wt_booldex = fits_df.variant_name=='None0None'
# wt_mean_bin = fits_df.loc[wt_booldex, xvar].iloc[0]

ax = plt.axes()
ax.hist(fits_df[xvar])
# ax.axvline(wt_mean_bin, color='red')
# Out:
# (array([15.,  0.,  0., 12.,  0.,  0.,  5.,  0.,  0., 11.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
for bamdf in dfs:

    # don't fit with any reads from unassigned bins
    bamdf = bamdf[bamdf.bin_number!=0].reset_index()
    print(f'fitting data from file {bamdf.source_file.iloc[0]}')

    fits_df = fitting.fit_bin_count_per_variant(bamdf, ycol='')
# Out:
# fitting data from file FLAG-Lib2_S4_L001_001_bam.csv.gz
# Fitting variant 1 of 1409 with 18 reads
# Fit variant with center 3.7176295288943733
# Fitting variant 2 of 1409 with 33 reads
# Fit variant with center 4.273682801808474
# Fitting variant 3 of 1409 with 46 reads
# Fit variant with center 4.851200530436621
# Fitting variant 4 of 1409 with 61 reads
# Fit variant with center 4.338965982796827
# Fitting variant 5 of 1409 with 64 reads
# Fit variant with center 4.30908341071223
# Fitting variant 6 of 1409 with 9 reads
# Fit variant with center 4.369066370978854
# Fitting variant 7 of 1409 with 10 reads
# Fit variant with center 5.011404304401801
# Fitting variant 8 of 1409 with 10 reads
# Fit variant with center 5.9999999999999964
# Fitting variant 9 of 1409 with 64 reads
# /root/venvs/.dms/lib/python3.6/site-packages/scipy/optimize/minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Fit variant with center 4.284540283769392
# Fitting variant 10 of 1409 with 9 reads
# Fit variant with center 5.165392758964622
# Fitting variant 11 of 1409 with 27 reads
# Fit variant with center 5.478033506058115
# Fitting variant 12 of 1409 with 30 reads
# Fit variant with center 4.345078641262425
# Fitting variant 13 of 1409 with 13 reads
# Fit variant with center 3.9817420465345648
# Fitting variant 14 of 1409 with 8 reads
# Fit variant with center 4.59265292142085
# Fitting variant 15 of 1409 with 48 reads
# Fit variant with center 4.698203095318065
# Fitting variant 16 of 1409 with 102 reads
# Fit variant with center 4.3847466423987855
# Fitting variant 17 of 1409 with 20 reads
# Fit variant with center 5.999999999999995
# Fitting variant 18 of 1409 with 9 reads
# Fit variant with center 4.300522335649769
# Fitting variant 19 of 1409 with 23 reads
# Fit variant with center 4.419344101573877
# Fitting variant 20 of 1409 with 50 reads
# Fit variant with center 4.220987730369315
# Fitting variant 21 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 22 of 1409 with 23 reads
# Fit variant with center 4.648413266608014
# Fitting variant 23 of 1409 with 13 reads
# Fit variant with center 5.999999999999993
# Fitting variant 24 of 1409 with 19 reads
# Fit variant with center 4.497617834017585
# Fitting variant 25 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 26 of 1409 with 93 reads
# Fit variant with center 4.807241944433282
# Fitting variant 27 of 1409 with 17 reads
# Fit variant with center 5.999999999999999
# Fitting variant 28 of 1409 with 19 reads
# Fit variant with center 3.995718113848245
# Fitting variant 29 of 1409 with 12 reads
# Fit variant with center 4.8032975759323
# Fitting variant 30 of 1409 with 13 reads
# Fit variant with center 4.145993897024174
# Fitting variant 31 of 1409 with 3 reads
# Fit variant with center 2.176349198361951
# Fitting variant 32 of 1409 with 19 reads
# Fit variant with center 3.995718113848245
# Fitting variant 33 of 1409 with 4 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 34 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 35 of 1409 with 9 reads
# Fit variant with center 2.957239929826147
# Fitting variant 36 of 1409 with 17 reads
# Fit variant with center 2.408331108782871e-22
# Fitting variant 37 of 1409 with 5 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 38 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 39 of 1409 with 56 reads
# Fit variant with center 4.449981091799657
# Fitting variant 40 of 1409 with 14 reads
# Fit variant with center 4.675080210822955
# Fitting variant 41 of 1409 with 170 reads
# Fit variant with center 4.735443539774883
# Fitting variant 42 of 1409 with 69 reads
# Fit variant with center 5.999999999972683
# Fitting variant 43 of 1409 with 112 reads
# Fit variant with center 4.610044100394676
# Fitting variant 44 of 1409 with 55 reads
# Fit variant with center 5.99999999999945
# Fitting variant 45 of 1409 with 2 reads
# Fit variant with center 3.4999976716215926
# Fitting variant 46 of 1409 with 14 reads
# Fit variant with center 2.0946007749932734
# Fitting variant 47 of 1409 with 19 reads
# Fit variant with center 4.015336032722231
# Fitting variant 48 of 1409 with 29 reads
# Fit variant with center 4.036972261703435
# Fitting variant 49 of 1409 with 43 reads
# Fit variant with center 5.882141336009472
# Fitting variant 50 of 1409 with 15 reads
# Fit variant with center 3.97563934198302
# Fitting variant 51 of 1409 with 33 reads
# Fit variant with center 5.256119375998845
# Fitting variant 52 of 1409 with 78 reads
# Fit variant with center 4.595575333239964
# Fitting variant 53 of 1409 with 104 reads
# Fit variant with center 4.314091108497937
# Fitting variant 54 of 1409 with 28 reads
# Fit variant with center 4.9869974088409235
# Fitting variant 55 of 1409 with 61 reads
# Fit variant with center 4.254281059437973
# Fitting variant 56 of 1409 with 66 reads
# Fit variant with center 4.321631076427675
# Fitting variant 57 of 1409 with 111 reads
# Fit variant with center 4.4558134166853876
# Fitting variant 58 of 1409 with 146 reads
# Fit variant with center 4.473893394501316
# Fitting variant 59 of 1409 with 37 reads
# Fit variant with center 5.8295732065726185
# Fitting variant 60 of 1409 with 57 reads
# Fit variant with center 4.426561499270667
# Fitting variant 61 of 1409 with 41 reads
# Fit variant with center 4.886004490771185
# Fitting variant 62 of 1409 with 37 reads
# Fit variant with center 4.666040933152386
# Fitting variant 63 of 1409 with 11 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 64 of 1409 with 22 reads
# Fit variant with center 5.999999999999999
# Fitting variant 65 of 1409 with 9 reads
# Fit variant with center 5.999999999999999
# Fitting variant 66 of 1409 with 8 reads
# Fit variant with center 5.999999999999999
# Fitting variant 67 of 1409 with 12 reads
# Fit variant with center 4.394472844348454
# Fitting variant 68 of 1409 with 6 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 69 of 1409 with 20 reads
# Fit variant with center 5.3046558152821435
# Fitting variant 70 of 1409 with 19 reads
# Fit variant with center 4.477152250256967
# Fitting variant 71 of 1409 with 19 reads
# Fit variant with center 5.1347150955811145
# Fitting variant 72 of 1409 with 23 reads
# Fit variant with center 3.0964174765371726
# Fitting variant 73 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 74 of 1409 with 9 reads
# Fit variant with center 5.999999999999999
# Fitting variant 75 of 1409 with 22 reads
# Fit variant with center 1.590089222717987
# Fitting variant 76 of 1409 with 68 reads
# Fit variant with center 3.426772579623445
# Fitting variant 77 of 1409 with 46 reads
# Fit variant with center 4.32686717748301
# Fitting variant 78 of 1409 with 37 reads
# Fit variant with center 4.298014287214391
# Fitting variant 79 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 80 of 1409 with 19 reads
# Fit variant with center 5.861774636539698e-16
# Fitting variant 81 of 1409 with 15 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 82 of 1409 with 19 reads
# Fit variant with center 3.8876696510616955
# Fitting variant 83 of 1409 with 10 reads
# Fit variant with center 5.999999999999977
# Fitting variant 84 of 1409 with 71 reads
# Fit variant with center 4.940235853776862
# Fitting variant 85 of 1409 with 84 reads
# Fit variant with center 4.3594946576615285
# Fitting variant 86 of 1409 with 36 reads
# Fit variant with center 4.360770642277634
# Fitting variant 87 of 1409 with 237 reads
# Fit variant with center 4.768831529154615
# Fitting variant 88 of 1409 with 259 reads
# Fit variant with center 4.705512483526913
# Fitting variant 89 of 1409 with 774 reads
# Fit variant with center 4.7426799551859755
# Fitting variant 90 of 1409 with 230 reads
# Fit variant with center 4.437802630512277
# Fitting variant 91 of 1409 with 242 reads
# Fit variant with center 4.63125921548925
# Fitting variant 92 of 1409 with 412 reads
# Fit variant with center 4.604300709156517
# Fitting variant 93 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 94 of 1409 with 18 reads
# Fit variant with center 5.999999999999999
# Fitting variant 95 of 1409 with 23 reads
# Fit variant with center 2.3408782693816064
# Fitting variant 96 of 1409 with 8 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 97 of 1409 with 16 reads
# Fit variant with center 3.975484168492352
# Fitting variant 98 of 1409 with 41 reads
# Fit variant with center 4.403633158848223
# Fitting variant 99 of 1409 with 112 reads
# Fit variant with center 4.615307949672969
# Fitting variant 100 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 101 of 1409 with 14 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 102 of 1409 with 11 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 103 of 1409 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 104 of 1409 with 18 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 105 of 1409 with 18 reads
# Fit variant with center 4.133665524300165
# Fitting variant 106 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 107 of 1409 with 5 reads
# Fit variant with center 4.435399486715866
# Fitting variant 108 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 109 of 1409 with 5 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 110 of 1409 with 21 reads
# Fit variant with center 4.454248839880659
# Fitting variant 111 of 1409 with 8 reads
# Fit variant with center 4.632491868953797
# Fitting variant 112 of 1409 with 16 reads
# Fit variant with center 4.27505166313152
# Fitting variant 113 of 1409 with 5 reads
# Fit variant with center 5.999999999999999
# Fitting variant 114 of 1409 with 3 reads
# Fit variant with center 3.91503752935507
# Fitting variant 115 of 1409 with 3 reads
# Fit variant with center 2.4257741684309426
# Fitting variant 116 of 1409 with 52 reads
# Fit variant with center 4.856559690851255
# Fitting variant 117 of 1409 with 5 reads
# Fit variant with center 5.999999999999539
# Fitting variant 118 of 1409 with 44 reads
# Fit variant with center 5.999999999999999
# Fitting variant 119 of 1409 with 39 reads
# Fit variant with center 4.311404482824188
# Fitting variant 120 of 1409 with 23 reads
# Fit variant with center 0.9096832267875169
# Fitting variant 121 of 1409 with 48 reads
# Fit variant with center 4.984884209045854
# Fitting variant 122 of 1409 with 23 reads
# Fit variant with center 5.123656344156975
# Fitting variant 123 of 1409 with 18 reads
# Fit variant with center 4.5235731222141125
# Fitting variant 124 of 1409 with 51 reads
# Fit variant with center 4.324380594673097
# Fitting variant 125 of 1409 with 64 reads
# Fit variant with center 4.206780351280288
# Fitting variant 126 of 1409 with 20 reads
# Fit variant with center 7.207918941947238e-16
# Fitting variant 127 of 1409 with 31 reads
# Fit variant with center 3.1815491004610394
# Fitting variant 128 of 1409 with 21 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 129 of 1409 with 27 reads
# Fit variant with center 4.2194470493654
# Fitting variant 130 of 1409 with 25 reads
# Fit variant with center 5.075667375064495
# Fitting variant 131 of 1409 with 66 reads
# Fit variant with center 4.883734666723808
# Fitting variant 132 of 1409 with 510 reads
# Fit variant with center 4.514504065228627
# Fitting variant 133 of 1409 with 69 reads
# Fit variant with center 4.583233902051875
# Fitting variant 134 of 1409 with 51 reads
# Fit variant with center 4.55536638078312
# Fitting variant 135 of 1409 with 44 reads
# Fit variant with center 4.68458721914991
# Fitting variant 136 of 1409 with 56 reads
# Fit variant with center 4.432735120616718
# Fitting variant 137 of 1409 with 26 reads
# Fit variant with center 4.695053299766735
# Fitting variant 138 of 1409 with 104 reads
# Fit variant with center 4.347073392797717
# Fitting variant 139 of 1409 with 34 reads
# Fit variant with center 4.556171832004362
# Fitting variant 140 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 141 of 1409 with 243 reads
# Fit variant with center 4.5829951116308845
# Fitting variant 142 of 1409 with 15 reads
# Fit variant with center 5.999999999999997
# Fitting variant 143 of 1409 with 80 reads
# Fit variant with center 5.438922024274306
# Fitting variant 144 of 1409 with 80 reads
# Fit variant with center 4.669297538862161
# Fitting variant 145 of 1409 with 75 reads
# Fit variant with center 4.425918883390245
# Fitting variant 146 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 147 of 1409 with 394 reads
# Fit variant with center 4.553317415301677
# Fitting variant 148 of 1409 with 537 reads
# Fit variant with center 4.539104036021223
# Fitting variant 149 of 1409 with 343 reads
# Fit variant with center 4.579032315388548
# Fitting variant 150 of 1409 with 17 reads
# Fit variant with center 2.4893684461705914
# Fitting variant 151 of 1409 with 12 reads
# Fit variant with center 0.7543569171746013
# Fitting variant 152 of 1409 with 15 reads
# Fit variant with center 5.17043538477855
# Fitting variant 153 of 1409 with 33 reads
# Fit variant with center 5.999999999999999
# Fitting variant 154 of 1409 with 71 reads
# Fit variant with center 4.5976103502587735
# Fitting variant 155 of 1409 with 77 reads
# Fit variant with center 4.460154310610164
# Fitting variant 156 of 1409 with 14 reads
# Fit variant with center 4.940923957984335
# Fitting variant 157 of 1409 with 30 reads
# Fit variant with center 4.333463457516304
# Fitting variant 158 of 1409 with 62 reads
# Fit variant with center 4.207974376590074
# Fitting variant 159 of 1409 with 10 reads
# Fit variant with center 2.7783080868079577
# Fitting variant 160 of 1409 with 13 reads
# Fit variant with center 2.9807642902654075
# Fitting variant 161 of 1409 with 36 reads
# Fit variant with center 0.46870920762192975
# Fitting variant 162 of 1409 with 12 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 163 of 1409 with 28 reads
# Fit variant with center 3.472685788016671
# Fitting variant 164 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 165 of 1409 with 78 reads
# Fit variant with center 5.999999999999999
# Fitting variant 166 of 1409 with 3 reads
# Fit variant with center 3.0000000114100462
# Fitting variant 167 of 1409 with 38 reads
# Fit variant with center 4.176993766557931
# Fitting variant 168 of 1409 with 37 reads
# Fit variant with center 4.271769464400073
# Fitting variant 169 of 1409 with 11 reads
# Fit variant with center 4.243314375454249
# Fitting variant 170 of 1409 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 171 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 172 of 1409 with 11 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 173 of 1409 with 3 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 174 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 175 of 1409 with 46 reads
# Fit variant with center 4.388808922411266
# Fitting variant 176 of 1409 with 56 reads
# Fit variant with center 4.848628443649174
# Fitting variant 177 of 1409 with 40 reads
# Fit variant with center 4.8713631987437775
# Fitting variant 178 of 1409 with 75 reads
# Fit variant with center 5.751040657847274
# Fitting variant 179 of 1409 with 40 reads
# Fit variant with center 4.265808432171498
# Fitting variant 180 of 1409 with 48 reads
# Fit variant with center 4.315770122638278
# Fitting variant 181 of 1409 with 140 reads
# Fit variant with center 4.73230396943124
# Fitting variant 182 of 1409 with 68 reads
# Fit variant with center 4.896609467643933
# Fitting variant 183 of 1409 with 11 reads
# Fit variant with center 2.570467094679059
# Fitting variant 184 of 1409 with 13 reads
# Fit variant with center 6.174036898194268e-16
# Fitting variant 185 of 1409 with 20 reads
# Fit variant with center 4.0969768476577855
# Fitting variant 186 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 187 of 1409 with 29 reads
# Fit failed with exception Optimal parameters not found: The maximum number of function evaluations is exceeded.
# Fitting variant 188 of 1409 with 54 reads
# Fit variant with center 4.392490885990491
# Fitting variant 189 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 190 of 1409 with 12 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 191 of 1409 with 13 reads
# Fit variant with center 5.3374220500527853e-17
# Fitting variant 192 of 1409 with 28 reads
# Fit variant with center 3.9980316017543283
# Fitting variant 193 of 1409 with 5 reads
# Fit variant with center 4.859306256664812
# Fitting variant 194 of 1409 with 12 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 195 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 196 of 1409 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 197 of 1409 with 52 reads
# Fit variant with center 4.726708692007406
# Fitting variant 198 of 1409 with 10 reads
# Fit variant with center 5.008920613375602
# Fitting variant 199 of 1409 with 9 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 200 of 1409 with 12 reads
# Fit variant with center 4.371335920950981
# Fitting variant 201 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 202 of 1409 with 18 reads
# Fit variant with center 4.481755747284176
# Fitting variant 203 of 1409 with 9 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 204 of 1409 with 55 reads
# Fit variant with center 4.8571272245865895
# Fitting variant 205 of 1409 with 15 reads
# Fit variant with center 4.127497485771208
# Fitting variant 206 of 1409 with 29 reads
# Fit variant with center 5.999999999997931
# Fitting variant 207 of 1409 with 76 reads
# Fit variant with center 4.523297808102343
# Fitting variant 208 of 1409 with 15 reads
# Fit variant with center 4.511375149431832
# Fitting variant 209 of 1409 with 27 reads
# Fit variant with center 4.524031284440927
# Fitting variant 210 of 1409 with 18 reads
# Fit variant with center 4.402211572499944
# Fitting variant 211 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 212 of 1409 with 4 reads
# Fit variant with center 2.3711529874547614
# Fitting variant 213 of 1409 with 103 reads
# Fit variant with center 4.924070614417335
# Fitting variant 214 of 1409 with 32 reads
# Fit variant with center 5.408167314516778
# Fitting variant 215 of 1409 with 9 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 216 of 1409 with 40 reads
# Fit variant with center 5.002988979239043
# Fitting variant 217 of 1409 with 43 reads
# Fit variant with center 4.551091144796923
# Fitting variant 218 of 1409 with 155 reads
# Fit variant with center 4.555372482063969
# Fitting variant 219 of 1409 with 150 reads
# Fit variant with center 5.999999999999999
# Fitting variant 220 of 1409 with 167 reads
# Fit variant with center 4.433821133388191
# Fitting variant 221 of 1409 with 87 reads
# Fit variant with center 4.004269111814754
# Fitting variant 222 of 1409 with 38 reads
# Fit variant with center 4.7686996475041274
# Fitting variant 223 of 1409 with 100 reads
# Fit variant with center 4.820301692828912
# Fitting variant 224 of 1409 with 50 reads
# Fit variant with center 2.0203985535345772e-13
# Fitting variant 225 of 1409 with 11 reads
# Fit variant with center 3.0165092349956226
# Fitting variant 226 of 1409 with 17 reads
# Fit variant with center 4.117440027276705
# Fitting variant 227 of 1409 with 19 reads
# Fit variant with center 4.65598633319564
# Fitting variant 228 of 1409 with 10 reads
# Fit variant with center 5.405882552154047
# Fitting variant 229 of 1409 with 49 reads
# Fit variant with center 4.364445350456437
# Fitting variant 230 of 1409 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 231 of 1409 with 12 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 232 of 1409 with 31 reads
# Fit variant with center 4.327682674047046
# Fitting variant 233 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 234 of 1409 with 5 reads
# Fit variant with center 2.499999998650641
# Fitting variant 235 of 1409 with 13 reads
# Fit variant with center 0.9166168256015654
# Fitting variant 236 of 1409 with 7 reads
# Fit variant with center 1.9999999988198944
# Fitting variant 237 of 1409 with 16 reads
# Fit variant with center 4.121419138366582
# Fitting variant 238 of 1409 with 43 reads
# Fit variant with center 3.959045768875337
# Fitting variant 239 of 1409 with 86 reads
# Fit variant with center 5.999999999999999
# Fitting variant 240 of 1409 with 31 reads
# Fit variant with center 3.395889893705313
# Fitting variant 241 of 1409 with 37 reads
# Fit variant with center 5.583539708199974
# Fitting variant 242 of 1409 with 111 reads
# Fit variant with center 4.2247975632775345
# Fitting variant 243 of 1409 with 48 reads
# Fit variant with center 4.099782824501359
# Fitting variant 244 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 245 of 1409 with 21 reads
# Fit variant with center 5.866997307117367
# Fitting variant 246 of 1409 with 5 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 247 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 248 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 249 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 250 of 1409 with 8 reads
# Fit variant with center 5.999999999999999
# Fitting variant 251 of 1409 with 38 reads
# Fit variant with center 4.200754538636548
# Fitting variant 252 of 1409 with 42 reads
# Fit variant with center 4.010346114806523
# Fitting variant 253 of 1409 with 59 reads
# Fit variant with center 4.098801588507011
# Fitting variant 254 of 1409 with 18 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 255 of 1409 with 39 reads
# Fit variant with center 4.173459639555577
# Fitting variant 256 of 1409 with 27 reads
# Fit variant with center 3.957317602874671
# Fitting variant 257 of 1409 with 10 reads
# Fit variant with center 1.5028212431189686e-14
# Fitting variant 258 of 1409 with 3 reads
# Fit variant with center 1.9999999791278196
# Fitting variant 259 of 1409 with 63 reads
# Fit variant with center 4.373513024459501
# Fitting variant 260 of 1409 with 58 reads
# Fit variant with center 5.346736501051719
# Fitting variant 261 of 1409 with 38 reads
# Fit variant with center 4.5425943817344745
# Fitting variant 262 of 1409 with 25 reads
# Fit variant with center 5.999999999999938
# Fitting variant 263 of 1409 with 56 reads
# Fit variant with center 4.351418994938988
# Fitting variant 264 of 1409 with 6 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 265 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 266 of 1409 with 2 reads
# Fit variant with center 3.4999976716215926
# Fitting variant 267 of 1409 with 34 reads
# Fit variant with center 5.999999999999999
# Fitting variant 268 of 1409 with 14 reads
# Fit variant with center 3.997210099547957
# Fitting variant 269 of 1409 with 25 reads
# Fit variant with center 4.019224292937985
# Fitting variant 270 of 1409 with 61 reads
# Fit variant with center 4.700112975961307
# Fitting variant 271 of 1409 with 25 reads
# Fit variant with center 5.999999999999914
# Fitting variant 272 of 1409 with 32 reads
# Fit variant with center 4.432688847100905
# Fitting variant 273 of 1409 with 232 reads
# Fit variant with center 4.568601671182159
# Fitting variant 274 of 1409 with 19 reads
# Fit variant with center 4.900554485335958
# Fitting variant 275 of 1409 with 102 reads
# Fit variant with center 5.999999999999999
# Fitting variant 276 of 1409 with 13 reads
# Fit variant with center 5.999999999999999
# Fitting variant 277 of 1409 with 41 reads
# Fit variant with center 4.363795784493038
# Fitting variant 278 of 1409 with 3 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 279 of 1409 with 36 reads
# Fit variant with center 5.999999999999706
# Fitting variant 280 of 1409 with 32 reads
# Fit variant with center 3.2970869356323295e-14
# Fitting variant 281 of 1409 with 5 reads
# Fit variant with center 2.1921125311153333
# Fitting variant 282 of 1409 with 43 reads
# Fit variant with center 4.001135241510751
# Fitting variant 283 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 284 of 1409 with 27 reads
# Fit variant with center 4.248899736903786
# Fitting variant 285 of 1409 with 17 reads
# Fit variant with center 4.548977312680995
# Fitting variant 286 of 1409 with 3 reads
# Fit variant with center 2.4257741684309426
# Fitting variant 287 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 288 of 1409 with 144 reads
# Fit variant with center 4.7146538380675365
# Fitting variant 289 of 1409 with 103 reads
# Fit variant with center 4.553672650365792
# Fitting variant 290 of 1409 with 10 reads
# Fit variant with center 2.7092245858838493
# Fitting variant 291 of 1409 with 3 reads
# Fit variant with center 0.5284443034917308
# Fitting variant 292 of 1409 with 51 reads
# Fit variant with center 5.999999999999999
# Fitting variant 293 of 1409 with 70 reads
# Fit variant with center 4.515917786297764
# Fitting variant 294 of 1409 with 17 reads
# Fit variant with center 5.151106953914678
# Fitting variant 295 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 296 of 1409 with 6 reads
# Fit variant with center 4.8648770426097805
# Fitting variant 297 of 1409 with 4 reads
# Fit variant with center 5.999999999999993
# Fitting variant 298 of 1409 with 28 reads
# Fit variant with center 4.289038229147152
# Fitting variant 299 of 1409 with 30 reads
# Fit variant with center 5.661776140727647
# Fitting variant 300 of 1409 with 5 reads
# Fit variant with center 5.999999999999999
# Fitting variant 301 of 1409 with 18 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 302 of 1409 with 47 reads
# Fit variant with center 4.25735443395813
# Fitting variant 303 of 1409 with 14 reads
# Fit variant with center 4.713967298268002
# Fitting variant 304 of 1409 with 25 reads
# Fit variant with center 4.856498475880412
# Fitting variant 305 of 1409 with 69 reads
# Fit variant with center 4.18809934060144
# Fitting variant 306 of 1409 with 73 reads
# Fit variant with center 4.236519547113295
# Fitting variant 307 of 1409 with 24 reads
# Fit variant with center 5.999999999999999
# Fitting variant 308 of 1409 with 181 reads
# Fit variant with center 4.487533903057092
# Fitting variant 309 of 1409 with 8 reads
# Fit variant with center 4.221658162175244
# Fitting variant 310 of 1409 with 16 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 311 of 1409 with 23 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 312 of 1409 with 3 reads
# Fit variant with center 3.8383159979144783
# Fitting variant 313 of 1409 with 31 reads
# Fit variant with center 4.051056228059688
# Fitting variant 314 of 1409 with 8 reads
# Fit variant with center 5.999999999999999
# Fitting variant 315 of 1409 with 7 reads
# Fit variant with center 3.9899297891329217
# Fitting variant 316 of 1409 with 33 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 317 of 1409 with 22 reads
# Fit variant with center 3.9433042481181415
# Fitting variant 318 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 319 of 1409 with 20 reads
# Fit variant with center 1.1116174825251664e-13
# Fitting variant 320 of 1409 with 3 reads
# Fit variant with center 3.8236503117708205
# Fitting variant 321 of 1409 with 30 reads
# Fit variant with center 5.777463156810087
# Fitting variant 322 of 1409 with 8 reads
# Fit variant with center 3.9162012492895816e-16
# Fitting variant 323 of 1409 with 4 reads
# Fit variant with center 2.500000116929317
# Fitting variant 324 of 1409 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 325 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 326 of 1409 with 43 reads
# Fit variant with center 4.548478750218425
# Fitting variant 327 of 1409 with 30 reads
# Fit variant with center 0.2941887020422575
# Fitting variant 328 of 1409 with 18 reads
# Fit variant with center 3.9552171576085544
# Fitting variant 329 of 1409 with 67 reads
# Fit variant with center 4.269826859929645
# Fitting variant 330 of 1409 with 40 reads
# Fit variant with center 4.66433906830053
# Fitting variant 331 of 1409 with 36 reads
# Fit variant with center 5.782574039934538
# Fitting variant 332 of 1409 with 58 reads
# Fit variant with center 4.376805297743596
# Fitting variant 333 of 1409 with 18 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 334 of 1409 with 21 reads
# Fit variant with center 5.999999999999999
# Fitting variant 335 of 1409 with 16 reads
# Fit variant with center 4.768793369869642
# Fitting variant 336 of 1409 with 6 reads
# Fit variant with center 2.2336804366617087
# Fitting variant 337 of 1409 with 8 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 338 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 339 of 1409 with 49 reads
# Fit variant with center 4.686738912358029
# Fitting variant 340 of 1409 with 68 reads
# Fit variant with center 4.556299319436398
# Fitting variant 341 of 1409 with 31 reads
# Fit variant with center 4.783556296192188
# Fitting variant 342 of 1409 with 96 reads
# Fit variant with center 4.281630985430934
# Fitting variant 343 of 1409 with 28 reads
# Fit variant with center 4.424898640900463
# Fitting variant 344 of 1409 with 135 reads
# Fit variant with center 4.467811105910355
# Fitting variant 345 of 1409 with 16 reads
# Fit variant with center 4.768793369869642
# Fitting variant 346 of 1409 with 43 reads
# Fit variant with center 5.529124460807143
# Fitting variant 347 of 1409 with 57 reads
# Fit variant with center 4.345041216806846
# Fitting variant 348 of 1409 with 25 reads
# Fit variant with center 4.695058951229538
# Fitting variant 349 of 1409 with 17 reads
# Fit variant with center 4.009627556676229
# Fitting variant 350 of 1409 with 17 reads
# Fit variant with center 4.437256583628703
# Fitting variant 351 of 1409 with 9 reads
# Fit variant with center 3.8674879182083224
# Fitting variant 352 of 1409 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 353 of 1409 with 31 reads
# Fit variant with center 5.115415181230681
# Fitting variant 354 of 1409 with 70 reads
# Fit variant with center 5.61392635360306
# Fitting variant 355 of 1409 with 45 reads
# Fit variant with center 4.369462750963355
# Fitting variant 356 of 1409 with 55 reads
# Fit variant with center 4.931416203545073
# Fitting variant 357 of 1409 with 140 reads
# Fit variant with center 4.422881244103785
# Fitting variant 358 of 1409 with 50 reads
# Fit variant with center 4.59700761646454
# Fitting variant 359 of 1409 with 34 reads
# Fit variant with center 4.544165558441253
# Fitting variant 360 of 1409 with 35 reads
# Fit variant with center 5.0486510790820045
# Fitting variant 361 of 1409 with 12 reads
# Fit variant with center 4.371335920950981
# Fitting variant 362 of 1409 with 92 reads
# Fit variant with center 4.459325910800132
# Fitting variant 363 of 1409 with 34 reads
# Fit variant with center 4.839367499437773
# Fitting variant 364 of 1409 with 11 reads
# Fit variant with center 5.60291966384299
# Fitting variant 365 of 1409 with 23 reads
# Fit variant with center 9.873681106029166e-18
# Fitting variant 366 of 1409 with 33 reads
# Fit variant with center 3.9278884664547373
# Fitting variant 367 of 1409 with 24 reads
# Fit variant with center 4.239664403839496
# Fitting variant 368 of 1409 with 23 reads
# Fit variant with center 5.999999999999983
# Fitting variant 369 of 1409 with 27 reads
# Fit variant with center 5.448482279814914
# Fitting variant 370 of 1409 with 21 reads
# Fit variant with center 1.1183693221346085
# Fitting variant 371 of 1409 with 21 reads
# Fit variant with center 4.016609242365345
# Fitting variant 372 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 373 of 1409 with 64 reads
# Fit variant with center 4.922623745127466
# Fitting variant 374 of 1409 with 36 reads
# Fit variant with center 5.999999999999999
# Fitting variant 375 of 1409 with 19 reads
# Fit variant with center 2.9859920070750645
# Fitting variant 376 of 1409 with 67 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 377 of 1409 with 29 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 378 of 1409 with 10 reads
# Fit variant with center 2.098074463452151
# Fitting variant 379 of 1409 with 17 reads
# Fit variant with center 3.9556828588674486
# Fitting variant 380 of 1409 with 54 reads
# Fit variant with center 3.9601382535811567
# Fitting variant 381 of 1409 with 17 reads
# Fit variant with center 3.9556828588674486
# Fitting variant 382 of 1409 with 12 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 383 of 1409 with 9 reads
# Fit variant with center 4.5111320529298204
# Fitting variant 384 of 1409 with 15 reads
# Fit variant with center 4.314656036345754
# Fitting variant 385 of 1409 with 28 reads
# Fit variant with center 4.135601955100599
# Fitting variant 386 of 1409 with 33 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 387 of 1409 with 52 reads
# Fit variant with center 3.997125331587246
# Fitting variant 388 of 1409 with 56 reads
# Fit variant with center 4.906717671340262
# Fitting variant 389 of 1409 with 18 reads
# Fit variant with center 2.9059732670842706
# Fitting variant 390 of 1409 with 29 reads
# Fit variant with center 4.0039858872037195
# Fitting variant 391 of 1409 with 4 reads
# Fit variant with center 4.348175811655772
# Fitting variant 392 of 1409 with 87 reads
# Fit variant with center 4.3472468111058795
# Fitting variant 393 of 1409 with 76 reads
# Fit variant with center 4.261137799698924
# Fitting variant 394 of 1409 with 82 reads
# Fit variant with center 4.443527873445235
# Fitting variant 395 of 1409 with 36 reads
# Fit variant with center 4.360955049945973
# Fitting variant 396 of 1409 with 25 reads
# Fit variant with center 4.414559963721021
# Fitting variant 397 of 1409 with 183 reads
# Fit variant with center 4.442854829435941
# Fitting variant 398 of 1409 with 10 reads
# Fit variant with center 2.4612774375660345
# Fitting variant 399 of 1409 with 37 reads
# Fit variant with center 5.6365379615715e-22
# Fitting variant 400 of 1409 with 26 reads
# Fit variant with center 4.926273675408495
# Fitting variant 401 of 1409 with 36 reads
# Fit variant with center 3.6200851956963547
# Fitting variant 402 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 403 of 1409 with 55 reads
# Fit variant with center 4.621675771946582
# Fitting variant 404 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 405 of 1409 with 17 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 406 of 1409 with 44 reads
# Fit variant with center 4.544397247418729
# Fitting variant 407 of 1409 with 20 reads
# Fit variant with center 6.213240396258112e-29
# Fitting variant 408 of 1409 with 25 reads
# Fit variant with center 4.645897916064099
# Fitting variant 409 of 1409 with 8 reads
# Fit variant with center 5.385648666734196
# Fitting variant 410 of 1409 with 11 reads
# Fit variant with center 4.8926982720678645
# Fitting variant 411 of 1409 with 9 reads
# Fit variant with center 5.506487502711554
# Fitting variant 412 of 1409 with 13 reads
# Fit variant with center 4.801482277544448
# Fitting variant 413 of 1409 with 16 reads
# Fit variant with center 1.6638609822632972e-17
# Fitting variant 414 of 1409 with 4 reads
# Fit variant with center 2.500002525767847
# Fitting variant 415 of 1409 with 56 reads
# Fit variant with center 3.9904433622878064
# Fitting variant 416 of 1409 with 29 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 417 of 1409 with 3 reads
# Fit variant with center 3.91503752935507
# Fitting variant 418 of 1409 with 19 reads
# Fit variant with center 4.485307376602654
# Fitting variant 419 of 1409 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 420 of 1409 with 9 reads
# Fit variant with center 5.194880183830642
# Fitting variant 421 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 422 of 1409 with 22 reads
# Fit variant with center 4.707085890836635
# Fitting variant 423 of 1409 with 33 reads
# Fit variant with center 5.8925114755187336
# Fitting variant 424 of 1409 with 49 reads
# Fit variant with center 4.329859891089708
# Fitting variant 425 of 1409 with 96 reads
# Fit variant with center 4.4228008363810885
# Fitting variant 426 of 1409 with 241 reads
# Fit variant with center 4.223348019151201
# Fitting variant 427 of 1409 with 68 reads
# Fit variant with center 5.999999999999999
# Fitting variant 428 of 1409 with 30 reads
# Fit variant with center 5.999965529657873
# Fitting variant 429 of 1409 with 16 reads
# Fit variant with center 4.608660619913293
# Fitting variant 430 of 1409 with 17 reads
# Fit variant with center 4.510034605205172
# Fitting variant 431 of 1409 with 6 reads
# Fit variant with center 3.976282684851254
# Fitting variant 432 of 1409 with 22 reads
# Fit variant with center 4.588242263361827
# Fitting variant 433 of 1409 with 13 reads
# Fit variant with center 2.88728582095938
# Fitting variant 434 of 1409 with 19 reads
# Fit variant with center 3.9998580341313046
# Fitting variant 435 of 1409 with 20 reads
# Fit variant with center 0.39397258267656093
# Fitting variant 436 of 1409 with 27 reads
# Fit variant with center 4.5111320529298204
# Fitting variant 437 of 1409 with 15 reads
# Fit variant with center 2.2462330151603647
# Fitting variant 438 of 1409 with 34 reads
# Fit variant with center 3.936871108242983
# Fitting variant 439 of 1409 with 12 reads
# Fit variant with center 4.159360649703243
# Fitting variant 440 of 1409 with 10 reads
# Fit variant with center 5.999999999999999
# Fitting variant 441 of 1409 with 27 reads
# Fit variant with center 0.6673918424062817
# Fitting variant 442 of 1409 with 2 reads
# Fit variant with center 1.4999985970328469
# Fitting variant 443 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 444 of 1409 with 4 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 445 of 1409 with 135 reads
# Fit variant with center 4.6662370218173015
# Fitting variant 446 of 1409 with 2 reads
# Fit variant with center 2.500000116929317
# Fitting variant 447 of 1409 with 12 reads
# Fit variant with center 4.371335920950981
# Fitting variant 448 of 1409 with 75 reads
# Fit variant with center 3.9993191197722084
# Fitting variant 449 of 1409 with 10 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 450 of 1409 with 24 reads
# Fit variant with center 4.510926673396055
# Fitting variant 451 of 1409 with 34 reads
# Fit variant with center 3.936871108242983
# Fitting variant 452 of 1409 with 7 reads
# Fit variant with center 4.238162437180757
# Fitting variant 453 of 1409 with 9 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 454 of 1409 with 12 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 455 of 1409 with 5 reads
# Fit variant with center 4.430447152195955
# Fitting variant 456 of 1409 with 12 reads
# Fit variant with center 5.999999999999999
# Fitting variant 457 of 1409 with 13 reads
# Fit variant with center 2.9704465986414528
# Fitting variant 458 of 1409 with 19 reads
# Fit variant with center 4.497617834017585
# Fitting variant 459 of 1409 with 32 reads
# Fit variant with center 4.4165688421396405
# Fitting variant 460 of 1409 with 21 reads
# Fit variant with center 4.016609242365345
# Fitting variant 461 of 1409 with 38 reads
# Fit variant with center 4.279917996813857
# Fitting variant 462 of 1409 with 37 reads
# Fit variant with center 4.327774846281851
# Fitting variant 463 of 1409 with 5 reads
# Fit variant with center 1.5028212431189686e-14
# Fitting variant 464 of 1409 with 298 reads
# Fit variant with center 4.466934145346069
# Fitting variant 465 of 1409 with 508 reads
# Fit variant with center 4.513566446436945
# Fitting variant 466 of 1409 with 493 reads
# Fit variant with center 4.58410052983285
# Fitting variant 467 of 1409 with 620 reads
# Fit variant with center 4.641399693381889
# Fitting variant 468 of 1409 with 190 reads
# Fit variant with center 4.49997789923487
# Fitting variant 469 of 1409 with 36 reads
# Fit variant with center 4.3362125329151
# Fitting variant 470 of 1409 with 65 reads
# Fit variant with center 4.675071080213157
# Fitting variant 471 of 1409 with 6 reads
# Fit variant with center 4.394472844348454
# Fitting variant 472 of 1409 with 16 reads
# Fit variant with center 4.783374834192226
# Fitting variant 473 of 1409 with 28 reads
# Fit variant with center 3.3009036750516607
# Fitting variant 474 of 1409 with 2 reads
# Fit variant with center 2.999999999892105
# Fitting variant 475 of 1409 with 21 reads
# Fit variant with center 4.5542436780247995
# Fitting variant 476 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 477 of 1409 with 14 reads
# Fit variant with center 5.999999999999634
# Fitting variant 478 of 1409 with 46 reads
# Fit variant with center 5.999999999999999
# Fitting variant 479 of 1409 with 100 reads
# Fit variant with center 4.34464513474872
# Fitting variant 480 of 1409 with 14 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 481 of 1409 with 3 reads
# Fit variant with center 1.3060835422681105
# Fitting variant 482 of 1409 with 34 reads
# Fit variant with center 0.6683910151508302
# Fitting variant 483 of 1409 with 2 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 484 of 1409 with 57 reads
# Fit variant with center 5.999999999999999
# Fitting variant 485 of 1409 with 90 reads
# Fit variant with center 4.570406001758986
# Fitting variant 486 of 1409 with 61 reads
# Fit variant with center 5.871125473147972
# Fitting variant 487 of 1409 with 36 reads
# Fit variant with center 4.714316311690928
# Fitting variant 488 of 1409 with 63 reads
# Fit variant with center 4.55594802285378
# Fitting variant 489 of 1409 with 57 reads
# Fit variant with center 4.7880549286564404
# Fitting variant 490 of 1409 with 35 reads
# Fit variant with center 4.959295641787635
# Fitting variant 491 of 1409 with 64 reads
# Fit variant with center 5.78949045919529
# Fitting variant 492 of 1409 with 8 reads
# Fit variant with center 5.215634079675032
# Fitting variant 493 of 1409 with 1 reads
# Fit variant with center 2.0089705041147874
# Fitting variant 494 of 1409 with 15 reads
# Fit variant with center 4.646581910954998
# Fitting variant 495 of 1409 with 31 reads
# Fit variant with center 4.292922556280204
# Fitting variant 496 of 1409 with 46 reads
# Fit variant with center 5.042073157324645
# Fitting variant 497 of 1409 with 183 reads
# Fit variant with center 4.194109208892987
# Fitting variant 498 of 1409 with 53 reads
# Fit variant with center 4.464048024297095
# Fitting variant 499 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 500 of 1409 with 4 reads
# Fit variant with center 2.500000000000018
# Fitting variant 501 of 1409 with 23 reads
# Fit variant with center 4.995659054613236
# Fitting variant 502 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 503 of 1409 with 4 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 504 of 1409 with 34 reads
# Fit variant with center 5.36827530637566
# Fitting variant 505 of 1409 with 14 reads
# Fit variant with center 5.646860931899457
# Fitting variant 506 of 1409 with 29 reads
# Fit variant with center 4.520104420945251
# Fitting variant 507 of 1409 with 14 reads
# Fit variant with center 4.011726903296033
# Fitting variant 508 of 1409 with 3 reads
# Fit variant with center 0.5284443034917308
# Fitting variant 509 of 1409 with 10 reads
# Fit variant with center 5.999999999999983
# Fitting variant 510 of 1409 with 33 reads
# Fit variant with center 5.999999999999999
# Fitting variant 511 of 1409 with 6 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 512 of 1409 with 16 reads
# Fit variant with center 4.462039428564393
# Fitting variant 513 of 1409 with 106 reads
# Fit variant with center 4.520995410681068
# Fitting variant 514 of 1409 with 4 reads
# Fit variant with center 2.4999999771419437
# Fitting variant 515 of 1409 with 13 reads
# Fit variant with center 4.145993897024174
# Fitting variant 516 of 1409 with 15 reads
# Fit variant with center 4.404899730098625
# Fitting variant 517 of 1409 with 29 reads
# Fit variant with center 4.131285352664053
# Fitting variant 518 of 1409 with 22 reads
# Fit variant with center 4.393015421929744
# Fitting variant 519 of 1409 with 5 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 520 of 1409 with 7 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 521 of 1409 with 7 reads
# Fit variant with center 4.238162437180757
# Fitting variant 522 of 1409 with 3 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 523 of 1409 with 11 reads
# Fit variant with center 5.491458574344452
# Fitting variant 524 of 1409 with 20 reads
# Fit variant with center 5.46619402242632
# Fitting variant 525 of 1409 with 22 reads
# Fit variant with center 5.999999999999999
# Fitting variant 526 of 1409 with 20 reads
# Fit variant with center 4.677433352149462
# Fitting variant 527 of 1409 with 14 reads
# Fit variant with center 4.543583113928388
# Fitting variant 528 of 1409 with 28 reads
# Fit variant with center 4.135601955100599
# Fitting variant 529 of 1409 with 39 reads
# Fit variant with center 4.732507851354402
# Fitting variant 530 of 1409 with 31 reads
# Fit variant with center 4.390096355724841
# Fitting variant 531 of 1409 with 39 reads
# Fit variant with center 4.274484853756967
# Fitting variant 532 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 533 of 1409 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 534 of 1409 with 38 reads
# Fit variant with center 4.718751711291835
# Fitting variant 535 of 1409 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 536 of 1409 with 263 reads
# Fit variant with center 4.697383273999578
# Fitting variant 537 of 1409 with 17 reads
# Fit variant with center 3.1414450805339813
# Fitting variant 538 of 1409 with 408 reads
# Fit variant with center 4.556245827242886
# Fitting variant 539 of 1409 with 4 reads
# Fit variant with center 5.999999999999993
# Fitting variant 540 of 1409 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 541 of 1409 with 111 reads
# Fit variant with center 4.438256165118881
# Fitting variant 542 of 1409 with 10 reads
# Fit variant with center 3.9104122983817686
# Fitting variant 543 of 1409 with 12 reads
# Fit variant with center 4.159360649703243
# Fitting variant 544 of 1409 with 40 reads
# Fit variant with center 5.999999999990088
# Fitting variant 545 of 1409 with 31 reads
# Fit variant with center 5.999999999999999
# Fitting variant 546 of 1409 with 85 reads
# Fit variant with center 4.445795952693099
# Fitting variant 547 of 1409 with 41 reads
# Fit variant with center 4.366763944973658
# Fitting variant 548 of 1409 with 21 reads
# Fit variant with center 5.866997307117367
# Fitting variant 549 of 1409 with 78 reads
# Fit variant with center 5.427422719736335
# Fitting variant 550 of 1409 with 28 reads
# Fit variant with center 4.642977875432303
# Fitting variant 551 of 1409 with 15 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 552 of 1409 with 8 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 553 of 1409 with 45 reads
# Fit variant with center 3.593813245248527
# Fitting variant 554 of 1409 with 26 reads
# Fit variant with center 3.9995456101301743
# Fitting variant 555 of 1409 with 13 reads
# Fit variant with center 4.797259560296575
# Fitting variant 556 of 1409 with 13 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 557 of 1409 with 11 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 558 of 1409 with 9 reads
# Fit variant with center 5.999999999999999
# Fitting variant 559 of 1409 with 4 reads
# Fit variant with center 5.999999999999999
# Fitting variant 560 of 1409 with 7 reads
# Fit variant with center 2.5000000001933578
# Fitting variant 561 of 1409 with 22 reads
# Fit variant with center 5.999999999999999
# Fitting variant 562 of 1409 with 12 reads
# Fit variant with center 5.970297157864671
# Fitting variant 563 of 1409 with 3 reads
# Fit variant with center 3.426992575564399
# Fitting variant 564 of 1409 with 93 reads
# Fit variant with center 4.482345999239634
# Fitting variant 565 of 1409 with 233 reads
# Fit variant with center 4.264780236311293
# Fitting variant 566 of 1409 with 69 reads
# Fit variant with center 4.486060002919391
# Fitting variant 567 of 1409 with 15 reads
# Fit variant with center 3.9910294597597193
# ...
# Fit variant with center 3.054844610129955
# Fitting variant 1252 of 1437 with 58 reads
# Fit variant with center 2.9385489394929394
# Fitting variant 1253 of 1437 with 44 reads
# Fit variant with center 3.0315782967909697
# Fitting variant 1254 of 1437 with 68 reads
# Fit variant with center 2.999896140326917
# Fitting variant 1255 of 1437 with 100 reads
# Fit variant with center 3.0999411925349825
# Fitting variant 1256 of 1437 with 126 reads
# Fit variant with center 3.0400790882686604
# Fitting variant 1257 of 1437 with 42 reads
# Fit variant with center 2.99997031839532
# Fitting variant 1258 of 1437 with 74 reads
# Fit variant with center 3.089859256201292
# Fitting variant 1259 of 1437 with 48 reads
# Fit variant with center 2.964322104476044
# Fitting variant 1260 of 1437 with 119 reads
# Fit variant with center 3.0993496762749344
# Fitting variant 1261 of 1437 with 39 reads
# Fit variant with center 2.999870419645704
# Fitting variant 1262 of 1437 with 131 reads
# Fit variant with center 3.03350485525557
# Fitting variant 1263 of 1437 with 15 reads
# Fit variant with center 0.5391492569804572
# Fitting variant 1264 of 1437 with 17 reads
# Fit variant with center 2.999930842907229
# Fitting variant 1265 of 1437 with 57 reads
# Fit variant with center 3.1020942164030236
# Fitting variant 1266 of 1437 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1267 of 1437 with 11 reads
# Fit variant with center 2.999526538058907
# Fitting variant 1268 of 1437 with 78 reads
# Fit variant with center 3.0931584244272567
# Fitting variant 1269 of 1437 with 20 reads
# Fit variant with center 3.0000000000000004
# Fitting variant 1270 of 1437 with 19 reads
# Fit variant with center 3.0
# Fitting variant 1271 of 1437 with 28 reads
# Fit variant with center 2.721887836244828
# Fitting variant 1272 of 1437 with 76 reads
# Fit variant with center 2.9696317738645486
# Fitting variant 1273 of 1437 with 2 reads
# Fit variant with center 3.4999976716215926
# Fitting variant 1274 of 1437 with 30 reads
# Fit variant with center 2.8328762761499675
# Fitting variant 1275 of 1437 with 16 reads
# Fit variant with center 3.0275166536106584
# Fitting variant 1276 of 1437 with 20 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1277 of 1437 with 27 reads
# Fit variant with center 2.938799928266681
# Fitting variant 1278 of 1437 with 33 reads
# Fit variant with center 2.9426352965012152
# Fitting variant 1279 of 1437 with 24 reads
# Fit variant with center 3.3600847811724246
# Fitting variant 1280 of 1437 with 20 reads
# Fit variant with center 3.0713135051380136
# Fitting variant 1281 of 1437 with 4 reads
# Fit variant with center 2.801587238695562
# Fitting variant 1282 of 1437 with 104 reads
# Fit variant with center 3.0127606465473016
# Fitting variant 1283 of 1437 with 10 reads
# Fit variant with center 3.1027008238430844
# Fitting variant 1284 of 1437 with 70 reads
# Fit variant with center 2.999651420489006
# Fitting variant 1285 of 1437 with 5 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1286 of 1437 with 10 reads
# Fit variant with center 5.999999999999999
# Fitting variant 1287 of 1437 with 5 reads
# Fit variant with center 3.2794540067732383
# Fitting variant 1288 of 1437 with 2 reads
# Fit variant with center 2.500000116929317
# Fitting variant 1289 of 1437 with 10 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1290 of 1437 with 7 reads
# Fit variant with center 3.0
# Fitting variant 1291 of 1437 with 30 reads
# Fit variant with center 2.55197244067184
# Fitting variant 1292 of 1437 with 57 reads
# Fit variant with center 3.033176496226154
# Fitting variant 1293 of 1437 with 4 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1294 of 1437 with 50 reads
# Fit variant with center 3.0673063481851583
# Fitting variant 1295 of 1437 with 30 reads
# Fit variant with center 2.767006430587962
# Fitting variant 1296 of 1437 with 9 reads
# Fit variant with center 2.7409255336637415
# Fitting variant 1297 of 1437 with 19 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1298 of 1437 with 28 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1299 of 1437 with 17 reads
# Fit variant with center 2.6943193810582375
# Fitting variant 1300 of 1437 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1301 of 1437 with 48 reads
# Fit variant with center 2.964322104476044
# Fitting variant 1302 of 1437 with 5 reads
# Fit variant with center 5.999999999999999
# Fitting variant 1303 of 1437 with 14 reads
# Fit variant with center 3.3201585318866127
# Fitting variant 1304 of 1437 with 14 reads
# Fit variant with center 3.40219193039231
# Fitting variant 1305 of 1437 with 29 reads
# Fit variant with center 2.940482425094356
# Fitting variant 1306 of 1437 with 14 reads
# Fit variant with center 2.857996468533953e-14
# Fitting variant 1307 of 1437 with 10 reads
# Fit variant with center 4.011407541106645
# Fitting variant 1308 of 1437 with 40 reads
# Fit variant with center 3.120730998144932
# Fitting variant 1309 of 1437 with 59 reads
# Fit variant with center 2.9609757796709166
# Fitting variant 1310 of 1437 with 31 reads
# Fit variant with center 3.1999106872281597
# Fitting variant 1311 of 1437 with 34 reads
# Fit variant with center 3.1614672246129487
# Fitting variant 1312 of 1437 with 9 reads
# Fit variant with center 2.860648976148185
# Fitting variant 1313 of 1437 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 1314 of 1437 with 29 reads
# Fit variant with center 2.99999999999998
# Fitting variant 1315 of 1437 with 86 reads
# Fit variant with center 3.130603428995272
# Fitting variant 1316 of 1437 with 8 reads
# Fit variant with center 2.8367783067522527
# Fitting variant 1317 of 1437 with 8 reads
# Fit variant with center 3.198412723494933
# Fitting variant 1318 of 1437 with 8 reads
# Fit variant with center 5.92430883434749
# Fitting variant 1319 of 1437 with 24 reads
# Fit variant with center 2.950518259456784
# Fitting variant 1320 of 1437 with 3 reads
# Fit variant with center 3.8383159979144783
# Fitting variant 1321 of 1437 with 4 reads
# Fit variant with center 3.198412723494933
# Fitting variant 1322 of 1437 with 22 reads
# Fit variant with center 3.273807837930401
# Fitting variant 1323 of 1437 with 5 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1324 of 1437 with 8 reads
# Fit variant with center 5.999999999999999
# Fitting variant 1325 of 1437 with 11 reads
# Fit variant with center 2.500000000006956
# Fitting variant 1326 of 1437 with 4 reads
# Fit variant with center 5.999999999997557
# Fitting variant 1327 of 1437 with 9 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1328 of 1437 with 38 reads
# Fit variant with center 2.966604804560088
# Fitting variant 1329 of 1437 with 87 reads
# Fit variant with center 3.0882913224993365
# Fitting variant 1330 of 1437 with 3 reads
# Fit variant with center 2.5730055919238652
# Fitting variant 1331 of 1437 with 13 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1332 of 1437 with 40 reads
# Fit variant with center 3.2956317535800395
# Fitting variant 1333 of 1437 with 36 reads
# Fit variant with center 3.094174409676063
# Fitting variant 1334 of 1437 with 11 reads
# Fit variant with center 3.1966578008072095
# Fitting variant 1335 of 1437 with 31 reads
# Fit variant with center 2.941245530693216
# Fitting variant 1336 of 1437 with 20 reads
# Fit variant with center 3.0203656689656166
# Fitting variant 1337 of 1437 with 8 reads
# Fit variant with center 2.801587238695562
# Fitting variant 1338 of 1437 with 14 reads
# Fit variant with center 3.2057036090894
# Fitting variant 1339 of 1437 with 10 reads
# Fit variant with center 3.1027008238430844
# Fitting variant 1340 of 1437 with 49 reads
# Fit variant with center 2.999992404066946
# Fitting variant 1341 of 1437 with 29 reads
# Fit variant with center 3.000585693727125
# Fitting variant 1342 of 1437 with 9 reads
# Fit variant with center 5.999999999999999
# Fitting variant 1343 of 1437 with 2 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 1344 of 1437 with 8 reads
# Fit variant with center 3.0351331105744483
# Fitting variant 1345 of 1437 with 57 reads
# Fit variant with center 3.045199117465201
# Fitting variant 1346 of 1437 with 7 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1347 of 1437 with 235 reads
# Fit variant with center 2.999975645628308
# Fitting variant 1348 of 1437 with 47 reads
# Fit variant with center 3.079921952669678
# Fitting variant 1349 of 1437 with 4 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 1350 of 1437 with 22 reads
# Fit variant with center 3.0000000000000084
# Fitting variant 1351 of 1437 with 67 reads
# Fit variant with center 3.021769449490245
# Fitting variant 1352 of 1437 with 9 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1353 of 1437 with 6 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 1354 of 1437 with 18 reads
# Fit variant with center 2.982939955373566
# Fitting variant 1355 of 1437 with 4 reads
# Fit variant with center 5.9999999999999885
# Fitting variant 1356 of 1437 with 30 reads
# Fit variant with center 2.535522194009334
# Fitting variant 1357 of 1437 with 34 reads
# Fit variant with center 3.032755811708215
# Fitting variant 1358 of 1437 with 15 reads
# Fit variant with center 3.1485744277835765
# Fitting variant 1359 of 1437 with 5 reads
# Fit variant with center 4.435399486715866
# Fitting variant 1360 of 1437 with 4 reads
# Fit variant with center 3.9162012492895816e-16
# Fitting variant 1361 of 1437 with 31 reads
# Fit variant with center 2.898994817574077
# Fitting variant 1362 of 1437 with 12 reads
# Fit variant with center 2.7420324300262906
# Fitting variant 1363 of 1437 with 38 reads
# Fit variant with center 3.03940368210663
# Fitting variant 1364 of 1437 with 48 reads
# Fit variant with center 3.0494817405432166
# Fitting variant 1365 of 1437 with 7 reads
# Fit variant with center 4.819625223810167
# Fitting variant 1366 of 1437 with 21 reads
# Fit variant with center 3.0965881519744762
# Fitting variant 1367 of 1437 with 12 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1368 of 1437 with 9 reads
# Fit variant with center 3.4999999999547766
# Fitting variant 1369 of 1437 with 27 reads
# Fit variant with center 3.1835094078322594
# Fitting variant 1370 of 1437 with 8 reads
# Fit variant with center 2.604740912776744
# Fitting variant 1371 of 1437 with 10 reads
# Fit variant with center 3.2517714574468517
# Fitting variant 1372 of 1437 with 18 reads
# Fit variant with center 3.0170600143184068
# Fitting variant 1373 of 1437 with 40 reads
# Fit variant with center 2.9464667719815387
# Fitting variant 1374 of 1437 with 19 reads
# Fit variant with center 2.9859920070750645
# Fitting variant 1375 of 1437 with 164 reads
# Fit variant with center 3.0630905855369863
# Fitting variant 1376 of 1437 with 365 reads
# Fit variant with center 3.034720426712391
# Fitting variant 1377 of 1437 with 205 reads
# Fit variant with center 3.093490161892206
# Fitting variant 1378 of 1437 with 406 reads
# Fit variant with center 3.075144024786513
# Fitting variant 1379 of 1437 with 363 reads
# Fit variant with center 2.99554367014984
# Fitting variant 1380 of 1437 with 346 reads
# Fit variant with center 3.0391973819990845
# Fitting variant 1381 of 1437 with 166 reads
# Fit variant with center 2.9453475399004807
# Fitting variant 1382 of 1437 with 209 reads
# Fit variant with center 3.019535482889086
# Fitting variant 1383 of 1437 with 8 reads
# Fit variant with center 2.801587238695562
# Fitting variant 1384 of 1437 with 4 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1385 of 1437 with 1 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1386 of 1437 with 12 reads
# Fit variant with center 2.927149128928483
# Fitting variant 1387 of 1437 with 39 reads
# Fit variant with center 3.143320043426902
# Fitting variant 1388 of 1437 with 57 reads
# Fit variant with center 2.9529984918126675
# Fitting variant 1389 of 1437 with 24 reads
# Fit variant with center 2.999880967349138
# Fitting variant 1390 of 1437 with 69 reads
# Fit variant with center 2.9998438036501844
# Fitting variant 1391 of 1437 with 5 reads
# Fit variant with center 0.6241106700027197
# Fitting variant 1392 of 1437 with 65 reads
# Fit variant with center 3.0580131016596157
# Fitting variant 1393 of 1437 with 11 reads
# Fit variant with center 3.2888248818014234
# Fitting variant 1394 of 1437 with 7 reads
# Fit variant with center 3.7305830789962777
# Fitting variant 1395 of 1437 with 1 reads
# Fit variant with center 3.9910294597597193
# Fitting variant 1396 of 1437 with 16 reads
# Fit variant with center 2.667092501567454
# Fitting variant 1397 of 1437 with 6 reads
# Fit variant with center 2.1370087710606405
# Fitting variant 1398 of 1437 with 47 reads
# Fit variant with center 3.002671975004193
# Fitting variant 1399 of 1437 with 32 reads
# Fit variant with center 2.9992903465865046
# Fitting variant 1400 of 1437 with 94 reads
# Fit variant with center 2.9122951884465063
# Fitting variant 1401 of 1437 with 4 reads
# Fit variant with center 5.999999999999993
# Fitting variant 1402 of 1437 with 11 reads
# Fit variant with center 2.6166844406843683
# Fitting variant 1403 of 1437 with 44 reads
# Fit variant with center 2.9999999999998392
# Fitting variant 1404 of 1437 with 5 reads
# Fit variant with center 3.2800287866369686
# Fitting variant 1405 of 1437 with 5 reads
# Fit variant with center 3.0000000000000178
# Fitting variant 1406 of 1437 with 3 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1407 of 1437 with 14 reads
# Fit variant with center 3.043399951796075
# Fitting variant 1408 of 1437 with 1 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 1409 of 1437 with 21 reads
# Fit variant with center 3.0112712728007933
# Fitting variant 1410 of 1437 with 29 reads
# Fit variant with center 3.0400994430752224
# Fitting variant 1411 of 1437 with 28 reads
# Fit variant with center 2.999671357250374
# Fitting variant 1412 of 1437 with 20 reads
# Fit variant with center 2.577470841694814
# Fitting variant 1413 of 1437 with 27 reads
# Fit variant with center 3.088315093672668
# Fitting variant 1414 of 1437 with 20 reads
# Fit variant with center 3.304587312575803
# Fitting variant 1415 of 1437 with 35 reads
# Fit variant with center 2.9999955960467517
# Fitting variant 1416 of 1437 with 16 reads
# Fit variant with center 2.9218857338312505
# Fitting variant 1417 of 1437 with 12 reads
# Fit variant with center 5.999999999999984
# Fitting variant 1418 of 1437 with 6 reads
# Fit variant with center 0.9909480646759222
# Fitting variant 1419 of 1437 with 10 reads
# Fit variant with center 3.0000000000000004
# Fitting variant 1420 of 1437 with 38 reads
# Fit variant with center 3.0332030773938405
# Fitting variant 1421 of 1437 with 11 reads
# Fit variant with center 3.1215084437506952
# Fitting variant 1422 of 1437 with 17 reads
# Fit variant with center 3.1362607315508084
# Fitting variant 1423 of 1437 with 9 reads
# Fit variant with center 3.1393509629710947
# Fitting variant 1424 of 1437 with 6 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1425 of 1437 with 246 reads
# Fit variant with center 2.982226435775603
# Fitting variant 1426 of 1437 with 173 reads
# Fit variant with center 2.972440707272739
# Fitting variant 1427 of 1437 with 262 reads
# Fit variant with center 3.0577438903744016
# Fitting variant 1428 of 1437 with 427 reads
# Fit variant with center 3.0638857894593996
# Fitting variant 1429 of 1437 with 40 reads
# Fit variant with center 3.2385606273484475
# Fitting variant 1430 of 1437 with 49 reads
# Fit variant with center 3.140679966557979
# Fitting variant 1431 of 1437 with 2 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1432 of 1437 with 5 reads
# Fit variant with center 2.9999999999999774
# Fitting variant 1433 of 1437 with 5 reads
# Fit variant with center 2.9999999999999774
# Fitting variant 1434 of 1437 with 2 reads
# Fit variant with center 3.4999976716215926
# Fitting variant 1435 of 1437 with 4 reads
# Fit variant with center 2.999999985098839
# Fitting variant 1436 of 1437 with 30 reads
# Fit variant with center 3.0
# Fitting variant 1437 of 1437 with 153240 reads
# Fit variant with center 3.045055283249307
# Wrote fits df to /root/projects/spikedisplay/notebooks/ACE2-Lib2_S2_L001_001_bam_gaussian_fits_df.csv

# %%
filenames = [fn for fn in os.listdir(os.getcwd()) if 'bam_gaussian_fits_df' in fn]
fit_dfs = [pd.read_csv(fn) for fn in filenames]

fitsdf = pd.concat(fit_dfs, ignore_index=True)

# %%
# Sub select the libraries we want to analyze
ace2lib1df = fitsdf[fitsdf.sample_library=='ACE2-Lib1']
flaglib1df = fitsdf[fitsdf.sample_library=='FLAG-Lib1']
ace2lib2df = fitsdf[fitsdf.sample_library=='ACE2-Lib2']
flaglib2df = fitsdf[fitsdf.sample_library=='FLAG-Lib2']

# %%
reload(normalization)
# Out:
# <module 'spikedisplay.normalization' from '/root/projects/spikedisplay/spikedisplay/normalization.py'>

# %%
ace2lib1df = normalization.wt_normalize(ace2lib1df)
ace2lib2df = normalization.wt_normalize(ace2lib2df)
flaglib1df = normalization.wt_normalize(flaglib1df)
flaglib2df = normalization.wt_normalize(flaglib2df)

mergeACE2 = ace2lib1df.merge(ace2lib2df, on='variant_name', how='left')
mergeFLAG = flaglib1df.merge(flaglib2df, on='variant_name', how='left')
# Out:
# /root/venvs/.dms/lib/python3.6/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /root/venvs/.dms/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.set_dpi(300)
ax = fig.add_subplot(111)
reads_threshold = 100
xvar = 'gaussian_center_log2_over_wt_x'
yvar = 'gaussian_center_log2_over_wt_y'
signal = 'ACE2'
xlabel = f'log2({signal}_variant/{signal}_wt) lib1'
ylabel = f'log2({signal}_variant/{signal}_wt) lib2'
df = mergeACE2
df = df[df.total_variant_reads_x>=reads_threshold]
N=len(df)
scatterkwargs = {
    'y': df[yvar],
    'x': df[xvar],
    'color': 'purple',
    'alpha': 0.1,
    's': 10
}

xlim = (-0.4, 0.4)
ylim = xlim
ax.set_ylim(xlim)
ax.set_xlim(xlim)

x_line = np.arange(np.min(xlim), np.max(xlim), 0.1)
y_line = fitting.line(x_line, 1, 0)

linekwargs = {
    'color': 'black',
    'linewidth': 0.5,
    'alpha': 1
}
ax.plot(x_line, y_line, **linekwargs)
ax.scatter(**scatterkwargs)
axrange = np.max(xlim) - np.min(xlim)
xy = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.8)
xyn = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.65)
ax.annotate(f'Min. reads per variant={reads_threshold}', xy=xy)
ax.annotate(f'# of variants={N}', xy=xyn)

ax.set_ylabel(ylabel)
ax.set_xlabel(xlabel)
plotting.remove_spines(ax)
plotting.format_ticks(ax)

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.set_dpi(300)
ax = fig.add_subplot(111)
reads_threshold = 10
xvar = 'gaussian_center_log2_over_wt_x'
yvar = 'gaussian_center_log2_over_wt_y'
signal = 'FLAG'
xlabel = f'log2({signal}_variant/{signal}_wt) lib1'
ylabel = f'log2({signal}_variant/{signal}_wt) lib2'
df = mergeFLAG
df = df[df.total_variant_reads_x>=reads_threshold]
N=len(df)
scatterkwargs = {
    'y': df[yvar],
    'x': df[xvar],
    'color': 'green',
    'alpha': 0.1,
    's': 10
}

xlim = (-0.4, 0.4)
ylim = xlim
ax.set_ylim(xlim)
ax.set_xlim(xlim)

x_line = np.arange(np.min(xlim), np.max(xlim), 0.1)
y_line = fitting.line(x_line, 1, 0)

linekwargs = {
    'color': 'black',
    'linewidth': 0.5,
    'alpha': 1
}
ax.plot(x_line, y_line, **linekwargs)
ax.scatter(**scatterkwargs)
axrange = np.max(xlim) - np.min(xlim)
xy = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.8)
xyn = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.65)
ax.annotate(f'Min. reads per variant={reads_threshold}', xy=xy)
ax.annotate(f'# of variants={N}', xy=xyn)

ax.set_ylabel(ylabel)
ax.set_xlabel(xlabel)
plotting.remove_spines(ax)
plotting.format_ticks(ax)

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
fitsdf = flaglib1df.copy()
fitsdf = fitsdf[fitsdf.total_variant_reads>=0]
scatterkwargs = {
    'y': fitsdf.total_variant_reads,
    'x': fitsdf.gaussian_center_log2_over_wt,
    'color': 'black',
    'alpha': 0.1,
    's': 10
}

ax.scatter(**scatterkwargs)

ax.set_yscale('log')
ax.set_xlim(-2, 2)
ax.set_ylim(1, 1000)
ax.set_yticks([1, 10, 100, 1000])
# Out:
# [<matplotlib.axis.YTick at 0x7febbeca7c50>,
#  <matplotlib.axis.YTick at 0x7febbeb0ba20>,
#  <matplotlib.axis.YTick at 0x7febbe6362e8>,
#  <matplotlib.axis.YTick at 0x7febc7958cc0>]

# %%
ace2lib1norm = flag_normalize(ace2lib1df, flaglib1df)
ace2lib2norm = flag_normalize(ace2lib2df, flaglib2df)

mergeACE2 = ace2lib1norm.merge(ace2lib2norm, on='variant_name', how='left')

# %%
fig = plt.figure(figsize=(2.5, 2.5))
ax = fig.add_subplot(111)
fig.set_dpi(300)

df = mergeACE2.copy()

kwargs = {
    'facecolor': 'white',
    'edgecolor': 'black',
    's': 5,
    'alpha': 0.6
}


x = df.ace2_center_over_flag_center_x
y = df.ace2_center_over_flag_center_y


ax.scatter(x, y, **kwargs)
ax.set_xlim(0, 2)
ax.set_ylim(0, 2)

# ax.set_yscale('log')
# ax.set_xscale('log')

plotting.remove_spines(ax)

# %%
wtdf = alldf[alldf.is_wt==True]
wtdf = wtdf[wtdf.sample_library=='ACE2-Lib1']
wtdf = wtdf[wtdf.bin_number!=0]
wtcountdf = wtdf.groupby(['variant_name', 'bin_number']).count().reset_index()

wtfitsdf = ace2lib1df[ace2lib1df.is_wt==True]
params = (
    wtfitsdf.loc[:, 'gaussian_a'].values[0],
    wtfitsdf.loc[:, 'gaussian_center'].values[0],
    wtfitsdf.loc[:, 'gaussian_stdev'].values[0]
)

fig = plt.figure(figsize=(3, 2))
fig.set_dpi(300)
ax = fig.add_subplot(111)

xscatter = wtcountdf.bin_number
yscatter = wtcountdf.seq_id
yscatter_norm = yscatter/np.sum(yscatter)

xsmooth = np.arange(0, np.max(xscatter)+1, 0.1)
ypred = fitting.gaussian(xsmooth, *params)

ax.scatter(xscatter, yscatter_norm, edgecolor='black', facecolor='white')
ax.plot(xsmooth, ypred, color='black')

ax.set_xlabel('Bin #')
ax.set_ylabel('Fraction of Reads')
# Out:
# Text(0, 0.5, 'Fraction of Reads')

# %%
fig = plt.figure(figsize=(3, 2))
fig.set_dpi(300)
ax = fig.add_subplot(111)

ax.hist(ace2lib1df .gaussian_center, bins=30)
ax.set_xlim(0, 5)

ax.set_xlabel('Mean bin from Gaussian fit')
ax.set_ylabel('Number of variants')
# Out:
# Text(0, 0.5, 'Number of variants')

# %%
fig = plt.figure(figsize=(3, 2))
fig.set_dpi(300)
ax = fig.add_subplot(111)

ax.hist(ace2lib1_df.bin_number)
ax.set_xlim(0, 5)

ax.set_xlabel('Bin #')
ax.set_ylabel('Number of reads')
# Out:
# Text(0, 0.5, 'Number of reads')

# %% [markdown]
# ## Compare effects to bloom lab data

# %%
datadir = os.path.join(constants.source_path, 'data/bloom_lab')
filename = '1-s2.0-S0092867420310035-mmc2.csv'
filepath = os.path.join(datadir, filename)
bloomdf = pd.read_csv(filepath)

bloomdf.loc[:, 'variant_name'] = bloomdf.mutation_RBD

# %%
plt.hist(fits_df.log2_ratio_to_wt)
# Out:
# (array([ 3.,  1.,  9.,  8., 21., 22., 17., 19.,  8.,  3.]),
#  array([-1.04116558, -0.97963602, -0.91810646, -0.8565769 , -0.79504734,
#         -0.73351778, -0.67198821, -0.61045865, -0.54892909, -0.48739953,
#         -0.42586997]),
#  <a list of 10 Patch objects>)

# %%
suffixes = [
    '_spikedisplay',
    '_bloom'
]

ACE2_bloom_merge = fits_df.merge(bloomdf,
                                   on='variant_name',
                                   how='left',
                                   suffixes=suffixes)

# %%
len(ACE2_bloom_merge.variant_name)
# Out:
# 111

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.set_dpi(300)
ax = fig.add_subplot(111)
reads_threshold = 200
df = ACE2_bloom_merge
df = df[df.total_variant_reads>=reads_threshold]
xvar = 'log2_ratio_to_wt'
yvar = 'bind_avg'
signal = 'ACE2'
xlabel = xvar
xlabel='bind_avg_spikedisplay'
ylabel = yvar
N=len(df)
scatterkwargs = {
    'y': df[yvar],
    'x': df[xvar],
    'color': 'purple',
    'alpha': 0.1,
    's': 10
}

xlim = (-4, 1)
ylim = (-4, 1)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
xlim = ax.get_xlim()
ylim = ax.get_ylim()

x_line = np.arange(np.min(xlim), np.max(xlim), 0.1)
y_line = fitting.line(x_line, 1, 0)

linekwargs = {
    'color': 'black',
    'linewidth': 0.5,
    'alpha': 1
}
ax.plot(x_line, y_line, **linekwargs)
ax.scatter(**scatterkwargs)
axrange = np.max(xlim) - np.min(xlim)
xy = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.8)
xyn = (np.min(xlim) + 0.1*axrange, np.max(ylim)*0.4)
ax.annotate(f'Min. reads per variant={reads_threshold}', xy=xy)
ax.annotate(f'# of variants={N}', xy=xyn)
ax.set_ylabel(ylabel)
ax.set_xlabel(xlabel)
plotting.remove_spines(ax)
plotting.format_ticks(ax)

# %%
df.sort_values(by='bind_avg_bloom', ascending=True).loc[:, ]
# Out:
#       is_wt_x mutant_aa_x wt_aa_at_mismatch_x  \
# 698     False           L                   R
# 1448    False           Y                   S
# 92      False           C                   G
# 95      False           C                   G
# 865     False           P                   A
#
#       mismatch_index_in_full_length_wt_seq_x  \
# 698                                      123
# 1448                                     107
# 92                                        85
# 95                                       116
# 865                                      144
#
#                          source_file_x sample_name_x library_name_x  \
# 698   ACE2-Lib1_S1_L001_001_bam.csv.gz          ACE2           Lib1
# 1448  ACE2-Lib1_S1_L001_001_bam.csv.gz          ACE2           Lib1
# 92    ACE2-Lib1_S1_L001_001_bam.csv.gz          ACE2           Lib1
# 95    ACE2-Lib1_S1_L001_001_bam.csv.gz          ACE2           Lib1
# 865   ACE2-Lib1_S1_L001_001_bam.csv.gz          ACE2           Lib1
#
#      variant_name sample_library_x  bin_number_x  ...  wildtype  mutant  \
# 698         R124L        ACE2-Lib1           2.5  ...         R       L
# 1448        S108Y        ACE2-Lib1           2.5  ...         S       Y
# 92           G86C        ACE2-Lib1           2.5  ...         G       C
# 95          G117C        ACE2-Lib1           2.5  ...         G       C
# 865         A145P        ACE2-Lib1           2.5  ...         A       P
#
#       mutation  mutation_RBD  bind_lib1  bind_lib2  bind_avg_bloom  expr_lib1  \
# 698      R454L         R124L      -4.67      -4.78           -4.73      -2.11
# 1448     S438Y         S108Y      -2.49      -2.62           -2.56      -2.22
# 92       G416C          G86C      -2.39      -2.33           -2.36      -2.17
# 95       G447C         G117C      -1.76      -1.79           -1.78      -0.43
# 865      A475P         A145P      -1.52      -1.72           -1.62      -1.44
#
#       expr_lib2  expr_avg
# 698       -2.19     -2.15
# 1448      -1.47     -1.85
# 92        -2.15     -2.16
# 95        -0.44     -0.43
# 865       -1.34     -1.39
#
# [5 rows x 62 columns]

# %%
plt.hist(bloomdf.bind_avg)
# Out:
# (array([ 295.,   72.,   67.,   57.,  116.,  140.,  204.,  387.,  786.,
#         1879.]),
#  array([-4.84 , -4.326, -3.812, -3.298, -2.784, -2.27 , -1.756, -1.242,
#         -0.728, -0.214,  0.3  ]),
#  <a list of 10 Patch objects>)

# %%
sample_library = 'ACE2-Lib1'
df = mergeACE2
reads_threshold = 50
df = df[df.total_variant_reads_x>=reads_threshold]
variants = list(df.variant_name.unique())

ncols = 6
nrows = int(np.round(len(variants)/ncols)+1)

fig = plt.figure(figsize=(8.5, 1.5*(nrows)))
fig.set_dpi(300)

i=1
for variant in variants:
    if variant == 'R124L':
        ax = fig.add_subplot(nrows, ncols, i)
        subdf = df[df.variant_name==variant]
        suballdf = alldf[alldf.variant_name==variant]
        suballdf = suballdf[suballdf.sample_library==sample_library]
        suballdf = suballdf[suballdf.bin_number!=0]
        subcountdf = suballdf.groupby(['variant_name', 'bin_number']).count().reset_index()
        params = (
            subdf.loc[:, 'gaussian_a_x'].values[0],
            subdf.loc[:, 'gaussian_center_x'].values[0],
            subdf.loc[:, 'gaussian_stdev_x'].values[0]
        )

        xscatter = subcountdf.bin_number
        yscatter = subcountdf.seq_id
        yscatter_norm = yscatter/np.sum(yscatter)

        xsmooth = np.arange(0, np.max(xscatter)+1, 0.1)
        ypred = fitting.gaussian(xsmooth, *params)

        ax.scatter(xscatter, yscatter_norm, edgecolor='black', facecolor='white')
        ax.plot(xsmooth, ypred, color='black')

        ax.set_xlabel('Bin #')
        ax.set_ylabel('Fraction of Reads')
        ax.set_title(variant)
        i+=1
    
plt.tight_layout()
